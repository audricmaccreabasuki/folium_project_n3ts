# %% [markdown]
# <a href="https://colab.research.google.com/github/lyajie2589/folium_project_n3ts/blob/main/AlyaJihanAzzahra_X_5_KotaCimahi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Template Tugas Project
#
# 1. import folium, pandas, geopandas, dan drive.
# 2. load data shapefile, pilih kota/kabupaten yang akan dianalisis
# 3. load data csv dan proses merge/join data
# 4. load peta choropleth

# %%
# Import Library

import folium
import pandas as pd
import geopandas as gpd
from google.colab import drive

# %% [markdown]
# Pilih nama kota / kabupaten kalian. jika tidak muncul pastikan namanya sesuai dengan nama di link berikut :
# https://geoservices.big.go.id/portal/apps/webappviewer/index.html?id=cb58db080712468cb4bfd408dbde3d70
#
# ![e92f69dd74b6160e4611eee8c27905f0.png](data:image/png;base64,...)

# %%
# Read Data Shapefile

drive.mount('/content/drive')
#drive.mount('/content/drive/MyDrive/ADMIN_INDO')

# Shapefile Admin Indonesia (tidak usah diubah2) Warning! File besar 1.4gb
indonesia_admin = gpd.read_file('/content/drive/MyDrive/ADMIN_INDO/ADMINISTRASI_AR_DESAKEL_10K.shp')

# Pilih Kota/Kabupaten yang ingin ditampilkan, contoh 'Kota Tangerang Selatan'
aoi_admin = indonesia_admin[indonesia_admin['WADMKK'] == 'Kota Cimahi']
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# CSV file path
csv_path = '/content/cimahi_kelurahan_KK.csv'

# Read shapefile
admin_gdf = aoi_admin

# Read CSV data
csv_data = pd.read_csv(csv_path, header = 0, delimiter= ';')

print(csv_data.head())
print(admin_gdf.head())
# Convert column names to lowercase
csv_data['Kelurahan'] = csv_data['Kelurahan'].str.lower().str.replace(' ', '')
admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.lower().str.replace(' ', '')
#csv_data['Jumlah_KK'] = csv_data['Jumlah_KK'].astype(str).str.replace('.', '')
#csv_data['Jumlah_KK'] = pd.to_numeric(csv_data['Jumlah_KK'])

# Fix typo to merge properly
#admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.replace('pondokjagungt', 'pondokjagung')
#csv_data['Kelurahan'] = csv_data['Kelurahan'].str.replace('perigibaru', 'parigibaru')

# Merge data
merged_data = pd.merge(admin_gdf, csv_data, left_on='NAMOBJ', right_on='Kelurahan', how='left')

# Convert to GeoDataFrame
merged_gdf = gpd.GeoDataFrame(merged_data, geometry=merged_data.geometry)

print(merged_gdf.head())
# Now you can use merged_gdf for further analysis and visualization
# Out:
#     Kelurahan  KepalaKeluarga
# 0      Melong           64420
# 1   Cibeureum           61218
# 2       Utama           34247
# 3  Leuwigajah           46040
# 4     Cibeber           29103
#        OBJECTID          NAMOBJ       FCODE  \
# 18792   18793.0           Baros  BA03070040
# 18848   18849.0         Cibabat  BA03070040
# 18859   18860.0         Cibeber  BA03070040
# 18892   18893.0  Cigugur Tengah  BA03070040
# 18927   18928.0          Cimahi  BA03070040
#
#                                       REMARK  \
# 18792  Hasil Delineasi Batas Desa Tahun 2018
# 18848  Hasil Delineasi Batas Desa Tahun 2018
# 18859  Hasil Delineasi Batas Desa Tahun 2018
# 18892  Hasil Delineasi Batas Desa Tahun 2018
# 18927  Hasil Delineasi Batas Desa Tahun 2018
#
#                                            METADATA     SRS_ID KDBBPS KDCBPS  \
# 18792  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 18848  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 18859  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 18892  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 18927  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#          KDCPUM KDEBPS  ...       WADMKK      WADMPR WIADKC WIADKK  WIADPR  \
# 18792  32.77.02   None  ...  Kota Cimahi  Jawa Barat   None   None    None
# 18848  32.77.03   None  ...  Kota Cimahi  Jawa Barat   None   None    None
# 18859  32.77.01   None  ...  Kota Cimahi  Jawa Barat   None   None    None
# 18892  32.77.02   None  ...  Kota Cimahi  Jawa Barat   None   None    None
# 18927  32.77.02   None  ...  Kota Cimahi  Jawa Barat   None   None    None
#
#        WIADKD                                               UUPP Shape_Leng  \
# 18792    None  Hasil Sinkronisasi Data Pemerintah Daerah Tahu...   0.088198
# 18848    None  Hasil Sinkronisasi Data Pemerintah Daerah Tahu...   0.092065
# 18859    None  Hasil Sinkronisasi Data Pemerintah Daerah Tahu...   0.085641
# 18892    None  Hasil Sinkronisasi Data Pemerintah Daerah Tahu...   0.087187
# 18927    None  Hasil Sinkronisasi Data Pemerintah Daerah Tahu...   0.039341
#
#       Shape_Area                                           geometry
# 18792   0.000231  POLYGON Z ((107.54625 -6.8861 0, 107.54624 -6....
# 18848   0.000246  POLYGON Z ((107.56175 -6.86166 0, 107.5618 -6....
# 18859   0.000299  POLYGON Z ((107.52976 -6.88691 0, 107.52974 -6...
# 18892   0.000193  POLYGON Z ((107.55646 -6.88964 0, 107.55644 -6...
# 18927   0.000047  POLYGON Z ((107.55169 -6.87224 0, 107.55166 -6...
#
# [5 rows x 28 columns]
#    OBJECTID         NAMOBJ       FCODE                                 REMARK  \
# 0   18793.0          baros  BA03070040  Hasil Delineasi Batas Desa Tahun 2018
# 1   18849.0        cibabat  BA03070040  Hasil Delineasi Batas Desa Tahun 2018
# 2   18860.0        cibeber  BA03070040  Hasil Delineasi Batas Desa Tahun 2018
# 3   18893.0  cigugurtengah  BA03070040  Hasil Delineasi Batas Desa Tahun 2018
# 4   18928.0         cimahi  BA03070040  Hasil Delineasi Batas Desa Tahun 2018
#
#                                        METADATA     SRS_ID KDBBPS KDCBPS  \
# 0  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 1  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 2  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 3  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 4  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#      KDCPUM KDEBPS  ... WIADKC WIADKK WIADPR WIADKD  \
# 0  32.77.02   None  ...   None   None   None   None
# 1  32.77.03   None  ...   None   None   None   None
# 2  32.77.01   None  ...   None   None   None   None
# 3  32.77.02   None  ...   None   None   None   None
# 4  32.77.02   None  ...   None   None   None   None
#
#                                                 UUPP  Shape_Leng Shape_Area  \
# 0  Hasil Sinkronisasi Data Pemerintah Daerah Tahu...    0.088198   0.000231
# 1  Hasil Sinkronisasi Data Pemerintah Daerah Tahu...    0.092065   0.000246
# 2  Hasil Sinkronisasi Data Pemerintah Daerah Tahu...    0.085641   0.000299
# 3  Hasil Sinkronisasi Data Pemerintah Daerah Tahu...    0.087187   0.000193
# 4  Hasil Sinkronisasi Data Pemerintah Daerah Tahu...    0.039341   0.000047
#
#                                             geometry      Kelurahan  \
# 0  POLYGON Z ((107.54625 -6.8861 0, 107.54624 -6....          baros
# 1  POLYGON Z ((107.56175 -6.86166 0, 107.5618 -6....        cibabat
# 2  POLYGON Z ((107.52976 -6.88691 0, 107.52974 -6...        cibeber
# 3  POLYGON Z ((107.55646 -6.88964 0, 107.55644 -6...  cigugurtengah
# 4  POLYGON Z ((107.55169 -6.87224 0, 107.55166 -6...         cimahi
#
#   KepalaKeluarga
# 0          20527
# 1          54657
# 2          29103
# 3          46969
# 4          13270
#
# [5 rows x 30 columns]
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Create a base map
m = folium.Map(location=[-6.871649, 107.543961], zoom_start=11)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name='choropleth',
    data=merged_gdf,
    columns=["Kelurahan", "KepalaKeluarga"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="Jumlah KK"
).add_to(m)

jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='Jumlah_KK',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['WADMKD','KepalaKeluarga'],
        aliases=['Kelurahan','Jumlah KK']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df248c4f7d6cf40b0759d2b7eaf6c9f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df248c4f7d6cf40b0759d2b7eaf6c9f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df248c4f7d6cf40b0759d2b7eaf6c9f8 = L.map(
#                 &quot;map_df248c4f7d6cf40b0759d2b7eaf6c9f8&quot;,
#                 {
#                     center: [-6.871649, 107.543961],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be7645ec71cbe4d4518f943c0cd4e21b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_be7645ec71cbe4d4518f943c0cd4e21b.addTo(map_df248c4f7d6cf40b0759d2b7eaf6c9f8);
#
#
#             var choropleth_e3f9fbb0788d8189cd9fae9b978beaf7 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_b2467a3f111ba339129909e377cc341e_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;4&quot;: case &quot;7&quot;: case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;11&quot;: case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_b2467a3f111ba339129909e377cc341e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b2467a3f111ba339129909e377cc341e = L.geoJson(null, {
#                 onEachFeature: geo_json_b2467a3f111ba339129909e377cc341e_onEachFeature,
#
#                 style: geo_json_b2467a3f111ba339129909e377cc341e_styler,
#         });
#
#         function geo_json_b2467a3f111ba339129909e377cc341e_add (data) {
#             geo_json_b2467a3f111ba339129909e377cc341e
#                 .addData(data);
#         }
#             geo_json_b2467a3f111ba339129909e377cc341e_add({&quot;bbox&quot;: [107.51031934800005, -6.932872999999972, 107.57618571500007, -6.827352232999942], &quot;features&quot;: [{&quot;bbox&quot;: [107.52500473500004, -6.9013364689999435, 107.54867898600008, -6.88308724999996], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[107.54625040300004, -6.88609667299994, 0.0], [107.54624044600007, -6.886134926999944, 0.0], [107.54621788500003, -6.88623363399995, 0.0], [107.54616207900006, -6.886395443999959, 0.0], [107.54635232600003, -6.8864339999999515, 0.0], [107.54626922000006, -6.886757865999925, 0.0], [107.54616462400008, -6.887176047999958, 0.0], [107.54607550300005, -6.887550186999931, 0.0], [107.54600444500005, -6.887776647999942, 0.0], [107.54593400800007, -6.888119286999938, 0.0], [107.54590336000007, -6.888263891999941, 0.0], [107.54584802100004, -6.888343800999962, 0.0], [107.54582435000003, -6.8884294899999645, 0.0], [107.54577332000008, -6.888602836999951, 0.0], [107.54574585200004, -6.888647983999931, 0.0], [107.54563142400008, -6.888624362999963, 0.0], [107.54544071500004, -6.888585571999954, 0.0], [107.54531590600004, -6.88856373699997, 0.0], [107.5452828080000

# %%
# Create a base map
m = folium.Map(location=[-6.871649, 107.543961], zoom_start=13)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name="Jumlah KK Kelurahan Cimahi",
    data=merged_gdf,
    columns=["Kelurahan", "KepalaKeluarga"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="Jumlah KK"
).add_to(m)

# Create/import data sma
data_sma = pd.read_csv('SMA_Negeri_Cimahi.csv')

data_sma['geometry'] = gpd.GeoSeries.from_wkt(data_sma['WKT'])

# Extract latitude and longitude from Point geometries
data_sma['latitude'] = data_sma['geometry'].apply(lambda x: x.y)
data_sma['longitude'] = data_sma['geometry'].apply(lambda x: x.x)

# Add markers to the map
# Create a marker layer
marker_layer = folium.FeatureGroup(name="SMAN Tangerang Selatan")

# Add markers to the layer
for i in range(0, len(data_sma)):
    folium.Marker([data_sma.iloc[i]['latitude'], data_sma.iloc[i]['longitude']], popup=data_sma.iloc[i]['name']).add_to(marker_layer)

m.add_child(marker_layer)

# Add Jumlah_KK layer map
jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='Jumlah_KK',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['NAMOBJ','KepalaKeluarga'],
        aliases=['Kelurahan','Jumlah KK']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2c37feb76f8d6d8f086601f5e8e8253 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2c37feb76f8d6d8f086601f5e8e8253&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2c37feb76f8d6d8f086601f5e8e8253 = L.map(
#                 &quot;map_f2c37feb76f8d6d8f086601f5e8e8253&quot;,
#                 {
#                     center: [-6.871649, 107.543961],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2feccfce2515a39cf89248ee928d4834 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2feccfce2515a39cf89248ee928d4834.addTo(map_f2c37feb76f8d6d8f086601f5e8e8253);
#
#
#             var choropleth_0bfddaa259d7e980a160cd9b8b785297 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_5690b5a4c8b60033f58602001c9e848a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;4&quot;: case &quot;7&quot;: case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;11&quot;: case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_5690b5a4c8b60033f58602001c9e848a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5690b5a4c8b60033f58602001c9e848a = L.geoJson(null, {
#                 onEachFeature: geo_json_5690b5a4c8b60033f58602001c9e848a_onEachFeature,
#
#                 style: geo_json_5690b5a4c8b60033f58602001c9e848a_styler,
#         });
#
#         function geo_json_5690b5a4c8b60033f58602001c9e848a_add (data) {
#             geo_json_5690b5a4c8b60033f58602001c9e848a
#                 .addData(data);
#         }
#             geo_json_5690b5a4c8b60033f58602001c9e848a_add({&quot;bbox&quot;: [107.51031934800005, -6.932872999999972, 107.57618571500007, -6.827352232999942], &quot;features&quot;: [{&quot;bbox&quot;: [107.52500473500004, -6.9013364689999435, 107.54867898600008, -6.88308724999996], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[107.54625040300004, -6.88609667299994, 0.0], [107.54624044600007, -6.886134926999944, 0.0], [107.54621788500003, -6.88623363399995, 0.0], [107.54616207900006, -6.886395443999959, 0.0], [107.54635232600003, -6.8864339999999515, 0.0], [107.54626922000006, -6.886757865999925, 0.0], [107.54616462400008, -6.887176047999958, 0.0], [107.54607550300005, -6.887550186999931, 0.0], [107.54600444500005, -6.887776647999942, 0.0], [107.54593400800007, -6.888119286999938, 0.0], [107.54590336000007, -6.888263891999941, 0.0], [107.54584802100004, -6.888343800999962, 0.0], [107.54582435000003, -6.8884294899999645, 0.0], [107.54577332000008, -6.888602836999951, 0.0], [107.54574585200004, -6.888647983999931, 0.0], [107.54563142400008, -6.888624362999963, 0.0], [107.54544071500004, -6.888585571999954, 0.0], [107.54531590600004, -6.88856373699997, 0.0], [107.5452828080000

# %% [markdown]
# Analysis Question:
# Kelurahan mana yang memiliki jumlah KK dengan kelas tertinggi (Merah Tua)?
#
# Jawab:
# melong, cibeureum
#
# Kelurahan apa saja yang tidak terdapat Sekolah Negeri?
#
# Jawab:
# cipageran, citeureup, padasuka, karangmekar, pasirkaliki, cigugurtengah, baros, cibeber, utama, cibeureum
