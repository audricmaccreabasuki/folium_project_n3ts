# %% [markdown]
# <a href="https://colab.research.google.com/github/mentariw-cipicapa/folium_project_n3ts/blob/main/Mentari_Kaila_Nurwahyuni_X_3_Kota_Malang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Template Tugas Project
#
# 1. import folium, pandas, geopandas, dan drive.
# 2. load data shapefile, pilih kota/kabupaten yang akan dianalisis
# 3. load data csv dan proses merge/join data
# 4. load peta choropleth

# %%
# Import Library

import folium
import pandas as pd
import geopandas as gpd
from google.colab import drive

# %% [markdown]
# Pilih nama kota / kabupaten kalian. jika tidak muncul pastikan namanya sesuai dengan nama di link berikut :
# https://geoservices.big.go.id/portal/apps/webappviewer/index.html?id=cb58db080712468cb4bfd408dbde3d70
#
# ![e92f69dd74b6160e4611eee8c27905f0.png](data:image/png;base64,...)

# %%
# Read Data Shapefile

drive.mount('/content/drive')

# Shapefile Admin Indonesia (tidak usah diubah2) Warning! File besar 1.4gb
indonesia_admin = gpd.read_file('/content/drive/MyDrive/ADMIN_INDO/ADMINISTRASI_AR_DESAKEL_10K.shp')

# Pilih Kota/Kabupaten yang ingin ditampilkan, contoh 'Kota Tangerang Selatan'
aoi_admin = indonesia_admin[indonesia_admin['WADMKK'] == 'Kota Malang']
# Out:
# Mounted at /content/drive

# %%
# CSV file path
csv_path = '/content/data_malang.csv'

# Read shapefile
admin_gdf = aoi_admin

# Read CSV data
csv_data = pd.read_csv(csv_path)

print(csv_data.head())
print(admin_gdf.head())
# Convert column names to lowercase
csv_data['Kelurahan'] = csv_data['Kelurahan'].str.lower().str.replace(' ', '')
admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.lower().str.replace(' ', '')
#csv_data['Jumlah_KK'] = csv_data['Jumlah_KK'].astype(str).str.replace('.', '')
#csv_data['Jumlah_KK'] = pd.to_numeric(csv_data['Jumlah_KK'])

# Fix typo to merge properly
#admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.replace('pondokjagungt', 'pondokjagung')
#csv_data['Kelurahan'] = csv_data['Kelurahan'].str.replace('perigibaru', 'parigibaru')

# Merge data
merged_data = pd.merge(admin_gdf, csv_data, left_on='NAMOBJ', right_on='Kelurahan', how='left')

# Convert to GeoDataFrame
merged_gdf = gpd.GeoDataFrame(merged_data, geometry=merged_data.geometry)

print(merged_gdf.head())
# Now you can use merged_gdf for further analysis and visualization
# Out:
#       Kelurahan  jumlah penduduk
# 0  Arjowinangun            12849
# 1     Tlogowaru             6913
# 2      Wonokoyo             7464
# 3       Bumiayu            20555
# 4        Buring            16399
#        OBJECTID         NAMOBJ       FCODE REMARK  \
# 81515   81524.0       Arjosari  BA03070040   None
# 81516   81525.0   Arjowinangun  BA03070040   None
# 81517   81526.0  Bakalankrajan  BA03070040   None
# 81518   81527.0   Balearjosari  BA03070040   None
# 81519   81528.0       Bandulan  BA03070040   None
#
#                                            METADATA     SRS_ID KDBBPS KDCBPS  \
# 81515  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 81516  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 81517  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 81518  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 81519  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#          KDCPUM KDEBPS  ...       WADMKK      WADMPR WIADKC WIADKK  WIADPR  \
# 81515  35.73.01   None  ...  Kota Malang  Jawa Timur   None   None    None
# 81516  35.73.03   None  ...  Kota Malang  Jawa Timur   None   None    None
# 81517  35.73.04   None  ...  Kota Malang  Jawa Timur   None   None    None
# 81518  35.73.01   None  ...  Kota Malang  Jawa Timur   None   None    None
# 81519  35.73.04   None  ...  Kota Malang  Jawa Timur   None   None    None
#
#        WIADKD                                               UUPP Shape_Leng  \
# 81515    None  Kesepakatan Teknis Batas Wilayah Administrasi ...   0.045204
# 81516    None  Kesepakatan Teknis Batas Wilayah Administrasi ...   0.064543
# 81517    None  Kesepakatan Teknis Batas Wilayah Administrasi ...   0.062899
# 81518    None  Kesepakatan Teknis Batas Wilayah Administrasi ...   0.071084
# 81519    None  Kesepakatan Teknis Batas Wilayah Administrasi ...   0.086227
#
#       Shape_Area                                           geometry
# 81515   0.000089  POLYGON Z ((112.66277 -7.93035 0, 112.66283 -7...
# 81516   0.000232  POLYGON Z ((112.64274 -8.03239 0, 112.64273 -8...
# 81517   0.000144  POLYGON Z ((112.60343 -7.99718 0, 112.60364 -7...
# 81518   0.000133  POLYGON Z ((112.6495 -7.91675 0, 112.6502 -7.9...
# 81519   0.000189  POLYGON Z ((112.59486 -7.9735 0, 112.59487 -7....
#
# [5 rows x 28 columns]
#    OBJECTID         NAMOBJ       FCODE REMARK  \
# 0   81524.0       arjosari  BA03070040   None
# 1   81525.0   arjowinangun  BA03070040   None
# 2   81526.0  bakalankrajan  BA03070040   None
# 3   81527.0   balearjosari  BA03070040   None
# 4   81528.0       bandulan  BA03070040   None
#
#                                        METADATA     SRS_ID KDBBPS KDCBPS  \
# 0  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 1  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 2  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 3  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 4  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#      KDCPUM KDEBPS  ... WIADKC WIADKK WIADPR WIADKD  \
# 0  35.73.01   None  ...   None   None   None   None
# 1  35.73.03   None  ...   None   None   None   None
# 2  35.73.04   None  ...   None   None   None   None
# 3  35.73.01   None  ...   None   None   None   None
# 4  35.73.04   None  ...   None   None   None   None
#
#                                                 UUPP  Shape_Leng Shape_Area  \
# 0  Kesepakatan Teknis Batas Wilayah Administrasi ...    0.045204   0.000089
# 1  Kesepakatan Teknis Batas Wilayah Administrasi ...    0.064543   0.000232
# 2  Kesepakatan Teknis Batas Wilayah Administrasi ...    0.062899   0.000144
# 3  Kesepakatan Teknis Batas Wilayah Administrasi ...    0.071084   0.000133
# 4  Kesepakatan Teknis Batas Wilayah Administrasi ...    0.086227   0.000189
#
#                                             geometry      Kelurahan  \
# 0  POLYGON Z ((112.66277 -7.93035 0, 112.66283 -7...       arjosari
# 1  POLYGON Z ((112.64274 -8.03239 0, 112.64273 -8...   arjowinangun
# 2  POLYGON Z ((112.60343 -7.99718 0, 112.60364 -7...  bakalankrajan
# 3  POLYGON Z ((112.6495 -7.91675 0, 112.6502 -7.9...   balearjosari
# 4  POLYGON Z ((112.59486 -7.9735 0, 112.59487 -7....       bandulan
#
#   jumlah penduduk
# 0            9584
# 1           12849
# 2           10371
# 3            8873
# 4           17224
#
# [5 rows x 30 columns]
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Create a base map
m = folium.Map(location=[-7.980000, 112.620000], zoom_start=11)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name='choropleth',
    data=merged_gdf,
    columns=["Kelurahan", "jumlah penduduk"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="jumlah penduduk"
).add_to(m)

jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='Jumlah_KK',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['WADMKD','jumlah penduduk'],
        aliases=['Kelurahan','jumlah penduduk']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_edb5f97b240d4a1f627e95ddae2a9732 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_edb5f97b240d4a1f627e95ddae2a9732&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_edb5f97b240d4a1f627e95ddae2a9732 = L.map(
#                 &quot;map_edb5f97b240d4a1f627e95ddae2a9732&quot;,
#                 {
#                     center: [-7.98, 112.62],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b9328a93ddfd4623d0f045daaba092f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0b9328a93ddfd4623d0f045daaba092f.addTo(map_edb5f97b240d4a1f627e95ddae2a9732);
#
#
#             var choropleth_fd6970b7293672e0bed265ba7f14cf81 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_2ba5dcd6936a2d6dd89e10a01e9cd1f6_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;6&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;17&quot;: case &quot;19&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;35&quot;: case &quot;40&quot;: case &quot;44&quot;: case &quot;51&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;7&quot;: case &quot;15&quot;: case &quot;20&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;37&quot;: case &quot;43&quot;: case &quot;46&quot;: case &quot;48&quot;: case &quot;50&quot;: case &quot;52&quot;: case &quot;54&quot;: case &quot;56&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;4&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;29&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;34&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;47&quot;: case &quot;53&quot;: case &quot;55&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;5&quot;: case &quot;27&quot;: case &quot;36&quot;: case &quot;49&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;8&quot;: case &quot;14&quot;: case &quot;16&quot;: case &quot;18&quot;: case &quot;28&quot;: case &quot;30&quot;: case &quot;33&quot;: case &quot;42&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_2ba5dcd6936a2d6dd89e10a01e9cd1f6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2ba5dcd6936a2d6dd89e10a01e9cd1f6 = L.geoJson(null, {
#                 onEachFeature: geo_json_2ba5dcd6936a2d6dd89e10a01e9cd1f6_onEachFeature,
#
#                 style: geo_json_2ba5dcd6936a2d6dd89e10a01e9cd1f6_styler,
#         });
#
#         function geo_json_2ba5dcd6936a2d6dd89e10a01e9cd1f6_add (data) {
#             geo_json_2ba5dcd6936a2d6dd89e10a01e9cd1f6
#                 .addData(data);
#         }
#             geo_json_2ba5dcd6936a2d6dd89e10a01e9cd1f6_add({&quot;bbox&quot;: [112.5689472460001, -8.051574676999962, 112.69377060300008, -7.910846883999966], &quot;features&quot;: [{&quot;bbox&quot;: [112.64940757000011, -7.936764701999948, 112.66442891300005, -7.925239667999961], &quot;geometry&quot;:

# %%
# Create a base map
m = folium.Map(location=[-7.980000, 112.620000], zoom_start=13)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name="data_malangl",
    data=merged_gdf,
    columns=["Kelurahan", "jumlah penduduk"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="Jumlah KK"
).add_to(m)

# Create/import data sma
data_sma = pd.read_csv('SMA_malang.csv')

data_sma['geometry'] = gpd.GeoSeries.from_wkt(data_sma['WKT'])

# Extract latitude and longitude from Point geometries
data_sma['latitude'] = data_sma['geometry'].apply(lambda x: x.y)
data_sma['longitude'] = data_sma['geometry'].apply(lambda x: x.x)

# Add markers to the map
# Create a marker layer
marker_layer = folium.FeatureGroup(name="SMA_malang")

# Add markers to the layer
for i in range(0, len(data_sma)):
    folium.Marker([data_sma.iloc[i]['latitude'], data_sma.iloc[i]['longitude']], popup=data_sma.iloc[i]['nama']).add_to(marker_layer)

m.add_child(marker_layer)

# Add Jumlah_KK layer map
jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='Jumlah_KK',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['NAMOBJ','jumlah penduduk'],
        aliases=['Kelurahan','Jumlah KK']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a234ce824ac9d06faa362b43419559de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a234ce824ac9d06faa362b43419559de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a234ce824ac9d06faa362b43419559de = L.map(
#                 &quot;map_a234ce824ac9d06faa362b43419559de&quot;,
#                 {
#                     center: [-7.98, 112.62],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_589d6ad476e1eb3d8c16f7847cb4988a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_589d6ad476e1eb3d8c16f7847cb4988a.addTo(map_a234ce824ac9d06faa362b43419559de);
#
#
#             var choropleth_29e3eb65e61686744195f7b49bd54bf2 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_f8cea27fae6ee2b2b08f1a47013ffdeb_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;6&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;17&quot;: case &quot;19&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;35&quot;: case &quot;40&quot;: case &quot;44&quot;: case &quot;51&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;7&quot;: case &quot;15&quot;: case &quot;20&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;37&quot;: case &quot;43&quot;: case &quot;46&quot;: case &quot;48&quot;: case &quot;50&quot;: case &quot;52&quot;: case &quot;54&quot;: case &quot;56&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;4&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;29&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;34&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;47&quot;: case &quot;53&quot;: case &quot;55&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;5&quot;: case &quot;27&quot;: case &quot;36&quot;: case &quot;49&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;8&quot;: case &quot;14&quot;: case &quot;16&quot;: case &quot;18&quot;: case &quot;28&quot;: case &quot;30&quot;: case &quot;33&quot;: case &quot;42&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_f8cea27fae6ee2b2b08f1a47013ffdeb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f8cea27fae6ee2b2b08f1a47013ffdeb = L.geoJson(null, {
#                 onEachFeature: geo_json_f8cea27fae6ee2b2b08f1a47013ffdeb_onEachFeature,
#
#                 style: geo_json_f8cea27fae6ee2b2b08f1a47013ffdeb_styler,
#         });
#
#         function geo_json_f8cea27fae6ee2b2b08f1a47013ffdeb_add (data) {
#             geo_json_f8cea27fae6ee2b2b08f1a47013ffdeb
#                 .addData(data);
#         }
#             geo_json_f8cea27fae6ee2b2b08f1a47013ffdeb_add({&quot;bbox&quot;: [112.5689472460001, -8.051574676999962, 112.69377060300008, -7.910846883999966], &quot;features&quot;: [{&quot;bbox&quot;: [112.64940757000011, -7.936764701999948, 112.66442891300005, -7.925239667999961], &quot;geometry&quot;:

# %% [markdown]
# Analysis Question:
# Kelurahan mana yang memiliki jumlah KK dengan kelas tertinggi (Merah Tua)?
#
# Jawab: Kelurahan yg memiliki jumlah penduduk terbanyak yaitu:
# 1. kota lama= 29,760
# 2. tanjungrejo= 27,947
# 3. pandan wangi= 32,454
# 4. bandung rejo sari= 30,441
#
# Kelurahan apa saja yang tidak terdapat Sekolah Negeri?
#
# Jawab:
# 1. cemoro kandang
# 2. lowok waru
# 3. purwodadi
# 4. tunjung sekar
# 5. karang besuki
# 6. dinoya
# 7. merjosari
# 8. balearjosari
# 9. tunggul wulung
# 10. tlogomas
# 11. tasik madu
