# %% [markdown]
# <a href="https://colab.research.google.com/github/rohaizzan/folium_project_n3ts/blob/main/Muhammad_Rohaizan_Razzak_X3_Magelang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Template Tugas Project
#
# 1. import folium, pandas, geopandas, dan drive.
# 2. load data shapefile, pilih kota/kabupaten yang akan dianalisis
# 3. load data csv dan proses merge/join data
# 4. load peta choropleth

# %%
# Import Library

import folium
import pandas as pd
import geopandas as gpd
from google.colab import drive

# %% [markdown]
# Pilih nama kota / kabupaten kalian. jika tidak muncul pastikan namanya sesuai dengan nama di link berikut :
# https://geoservices.big.go.id/portal/apps/webappviewer/index.html?id=cb58db080712468cb4bfd408dbde3d70
#
# ![e92f69dd74b6160e4611eee8c27905f0.png](data:image/png;base64,...)

# %%
# Read Data Shapefile

drive.mount('/content/drive')

# Shapefile Admin Indonesia (tidak usah diubah2) Warning! File besar 1.4gb
indonesia_admin = gpd.read_file('/content/drive/MyDrive/ADMIN_INDO/ADMINISTRASI_AR_DESAKEL_10K.shp')

# Pilih Kota/Kabupaten yang ingin ditampilkan, contoh 'Kota Tangerang Selatan'
aoi_admin = indonesia_admin[indonesia_admin['WADMKK'] == 'Kota Magelang']
# Out:
# Mounted at /content/drive

# %%
# CSV file path
csv_path = 'data magelang revisi mulu.csv'

# Read shapefile
admin_gdf = aoi_admin

# Read CSV data
csv_data = pd.read_csv(csv_path)

print(csv_data.head())
print(admin_gdf.head())
# Convert column names to lowercase
csv_data['Kelurahan'] = csv_data['Kelurahan'].str.lower().str.replace(' ', '')
admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.lower().str.replace(' ', '')
#csv_data['jumlah penduduk (jiwa)'] = csv_data['Jumlah penduduk (jiwa)'].astype(str).str.replace('.', '')
#csv_data['Jumlah penduduk (jiwa)'] = pd.to_numeric(csv_data['Jumlah penduduk (jiwa) '])

# Fix typo to merge properly
#admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.replace('Husein Sastranegara ', 'HUSEN SASTRANEGARA')
#csv_data['Kelurahan'] = csv_data['Kelurahan'].str.replace('perigibaru', 'parigibaru')

# Merge data
merged_data = pd.merge(admin_gdf, csv_data, left_on='NAMOBJ', right_on='Kelurahan', how='left')

# Convert to GeoDataFrame
merged_gdf = gpd.GeoDataFrame(merged_data, geometry=merged_data.geometry)

print(merged_gdf.head())
# Now you can use merged_gdf for further analysis and visualization
# Out:
#               Kelurahan  jumlah penduduk
# 0      Magelang Selatan            42258
# 1  Rejowinangun Selatan             8192
# 2             Magersari             8525
# 3      Jurangombo Utara             4321
# 4    Jurangombo Selatan             7363
#       OBJECTID           NAMOBJ       FCODE                    REMARK  \
# 2605    2606.0          cacaban  BA03070040                      None
# 2868    2869.0         gelangan  BA03070040                      None
# 3195    3196.0  jurangomboutara  BA03070040  Pemotongan Dari Data Bps
# 3651    3652.0       kedungsari  BA03070040                      None
# 3711    3712.0       kemirirejo  BA03070040                      None
#
#                                           METADATA     SRS_ID KDBBPS KDCBPS  \
# 2605  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 2868  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 3195  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 3651  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 3711  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#         KDCPUM KDEBPS  ...         WADMKK       WADMPR WIADKC WIADKK  WIADPR  \
# 2605  33.71.03   None  ...  Kota Magelang  Jawa Tengah   None   None    None
# 2868  33.71.03   None  ...  Kota Magelang  Jawa Tengah   None   None    None
# 3195  33.71.01   None  ...  Kota Magelang  Jawa Tengah   None   None    None
# 3651  33.71.02   None  ...  Kota Magelang  Jawa Tengah   None   None    None
# 3711  33.71.03   None  ...  Kota Magelang  Jawa Tengah   None   None    None
#
#       WIADKD                     UUPP Shape_Leng Shape_Area  \
# 2605    None  Data RBI Skala 1:25.000   0.036813   0.000071
# 2868    None  Data RBI Skala 1:25.000   0.055120   0.000076
# 3195    None  Data RBI Skala 1:25.000   0.041567   0.000049
# 3651    None  Data RBI Skala 1:25.000   0.067951   0.000099
# 3711    None  Data RBI Skala 1:25.000   0.069827   0.000103
#
#                                                geometry
# 2605  POLYGON Z ((110.21817 -7.47693 0, 110.21732 -7...
# 2868  POLYGON Z ((110.22105 -7.46839 0, 110.22067 -7...
# 3195  POLYGON Z ((110.21286 -7.49336 0, 110.21274 -7...
# 3651  POLYGON Z ((110.2315 -7.44487 0, 110.2315 -7.4...
# 3711  POLYGON Z ((110.22098 -7.4854 0, 110.21966 -7....
#
# [5 rows x 28 columns]
#    OBJECTID           NAMOBJ       FCODE                    REMARK  \
# 0    2606.0          cacaban  BA03070040                      None
# 1    2869.0         gelangan  BA03070040                      None
# 2    3196.0  jurangomboutara  BA03070040  Pemotongan Dari Data Bps
# 3    3652.0       kedungsari  BA03070040                      None
# 4    3712.0       kemirirejo  BA03070040                      None
#
#                                        METADATA     SRS_ID KDBBPS KDCBPS  \
# 0  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 1  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 2  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 3  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 4  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#      KDCPUM KDEBPS  ... WIADKC WIADKK WIADPR WIADKD                     UUPP  \
# 0  33.71.03   None  ...   None   None   None   None  Data RBI Skala 1:25.000
# 1  33.71.03   None  ...   None   None   None   None  Data RBI Skala 1:25.000
# 2  33.71.01   None  ...   None   None   None   None  Data RBI Skala 1:25.000
# 3  33.71.02   None  ...   None   None   None   None  Data RBI Skala 1:25.000
# 4  33.71.03   None  ...   None   None   None   None  Data RBI Skala 1:25.000
#
#    Shape_Leng Shape_Area                                           geometry  \
# 0    0.036813   0.000071  POLYGON Z ((110.21817 -7.47693 0, 110.21732 -7...
# 1    0.055120   0.000076  POLYGON Z ((110.22105 -7.46839 0, 110.22067 -7...
# 2    0.041567   0.000049  POLYGON Z ((110.21286 -7.49336 0, 110.21274 -7...
# 3    0.067951   0.000099  POLYGON Z ((110.2315 -7.44487 0, 110.2315 -7.4...
# 4    0.069827   0.000103  POLYGON Z ((110.22098 -7.4854 0, 110.21966 -7....
#
#          Kelurahan jumlah penduduk
# 0          cacaban            8178
# 1         gelangan            8479
# 2  jurangomboutara            4321
# 3       kedungsari            7341
# 4       kemirirejo            5766
#
# [5 rows x 30 columns]
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Create a base map
m = folium.Map(location=[ -7.4667, 110.2167], zoom_start=11)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name='choropleth',
    data=merged_gdf,
    columns=["Kelurahan", "jumlah penduduk"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="Jumlah Penduduk"
).add_to(m)

jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='jumlah penduduk',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['WADMKD','jumlah penduduk'],
        aliases=['Kelurahan','Jumlah Penduduk']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2d4bb44038ced638c81531c78bcb4b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2d4bb44038ced638c81531c78bcb4b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2d4bb44038ced638c81531c78bcb4b6 = L.map(
#                 &quot;map_e2d4bb44038ced638c81531c78bcb4b6&quot;,
#                 {
#                     center: [-7.4667, 110.2167],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6666cf5159d1e41182b1b192c5aba92 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a6666cf5159d1e41182b1b192c5aba92.addTo(map_e2d4bb44038ced638c81531c78bcb4b6);
#
#
#             var choropleth_3f165efeecc97d1b35e996d605993b17 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_7f6ded6ff506530db221971b13cc5fa9_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;5&quot;: case &quot;8&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;7&quot;: case &quot;14&quot;: case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_7f6ded6ff506530db221971b13cc5fa9_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7f6ded6ff506530db221971b13cc5fa9 = L.geoJson(null, {
#                 onEachFeature: geo_json_7f6ded6ff506530db221971b13cc5fa9_onEachFeature,
#
#                 style: geo_json_7f6ded6ff506530db221971b13cc5fa9_styler,
#         });
#
#         function geo_json_7f6ded6ff506530db221971b13cc5fa9_add (data) {
#             geo_json_7f6ded6ff506530db221971b13cc5fa9
#                 .addData(data);
#         }
#             geo_json_7f6ded6ff506530db221971b13cc5fa9_add({&quot;bbox&quot;: [110.19889230800004, -7.5060269999999605, 110.23747636700006, -7.433506000999955], &quot;features&quot;: [{&quot;bbox&quot;: [110.20570663700005, -7.482727000999944, 110.21817100000004, -7.473776000999976], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[110.21817100000004, -7.476926999999932, 0.0], [110.21732300000008, -7.477724999999964, 0.0], [110.21723000000009, -7.4785479999999325, 0.0], [110.21718800000008, -7.478937999999971, 0.0], [110.21718800000008, -7.47894200099995, 0.0], [110.21717700000005, -7.479108999999937, 0.0], [110.21720200000004, -7.479772999999966, 0.0], [110.21719900000005, -7.479957999999954, 0.0], [110.21719300000007, -7.479986999999937, 0.0], [110.21689600000008, -7.480677000999947, 0.0], [110.21676500000007, -7.481050000999971, 0.0], [110.21670400000005, -7.481286000999944, 0.0], [110.21593400000006, -7.481621000999951, 0.0], [110.21502100000004, -7.481777000999955, 0.0], [110.21402899900005, -7.481794998999931, 0.0], [110.21358000000004, -7.482424999999978, 0.0], [110.21356200000008, -7.4824429999999325, 0.0], [110.21328100000005, -7.482657999999958, 0.0], [110.21308000000005, -7.482727000999944, 0.0], [110.21282800000006, -7.482726000999946, 0.0], [110.21182599900004, -7.48261200099995, 0.0], [110.21156600000006, -

# %%
# Create a base map
m = folium.Map(location=[-7.4667, 110.2167], zoom_start=13)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name='choropleth',
    data=merged_gdf,
    columns=["Kelurahan", "jumlah penduduk"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="Jumlah Penduduk"
).add_to(m)

# Create/import data sma
data_sma = pd.read_csv('SMA magelang.csv')

data_sma['geometry'] = gpd.GeoSeries.from_wkt(data_sma['WKT'])

# Extract latitude and longitude from Point geometries
data_sma['latitude'] = data_sma['geometry'].apply(lambda x: x.y)
data_sma['longitude'] = data_sma['geometry'].apply(lambda x: x.x)

# Add markers to the map
# Create a marker layer
marker_layer = folium.FeatureGroup(name="SMA magelang")

# Add markers to the layer
for i in range(0, len(data_sma)):
    folium.Marker([data_sma.iloc[i]['latitude'], data_sma.iloc[i]['longitude']], popup=data_sma.iloc[i]['nama']).add_to(marker_layer)

m.add_child(marker_layer)

# Add Jumlah_KK layer map
jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='jumlah penduduk',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['WADMKD','jumlah penduduk'],
        aliases=['Kelurahan','Jumlah Penduduk']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1fe13eca0618c52a6fa7d99d82cae3c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1fe13eca0618c52a6fa7d99d82cae3c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1fe13eca0618c52a6fa7d99d82cae3c = L.map(
#                 &quot;map_b1fe13eca0618c52a6fa7d99d82cae3c&quot;,
#                 {
#                     center: [-7.4667, 110.2167],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c8433bcf0ad48ad07b2df30bb6ecb947 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c8433bcf0ad48ad07b2df30bb6ecb947.addTo(map_b1fe13eca0618c52a6fa7d99d82cae3c);
#
#
#             var choropleth_0df71d9572c41c7ba75c22e70dfd545f = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_e63ffa77a274e9209f264eafc9128642_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;5&quot;: case &quot;8&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;7&quot;: case &quot;14&quot;: case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_e63ffa77a274e9209f264eafc9128642_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e63ffa77a274e9209f264eafc9128642 = L.geoJson(null, {
#                 onEachFeature: geo_json_e63ffa77a274e9209f264eafc9128642_onEachFeature,
#
#                 style: geo_json_e63ffa77a274e9209f264eafc9128642_styler,
#         });
#
#         function geo_json_e63ffa77a274e9209f264eafc9128642_add (data) {
#             geo_json_e63ffa77a274e9209f264eafc9128642
#                 .addData(data);
#         }
#             geo_json_e63ffa77a274e9209f264eafc9128642_add({&quot;bbox&quot;: [110.19889230800004, -7.5060269999999605, 110.23747636700006, -7.433506000999955], &quot;features&quot;: [{&quot;bbox&quot;: [110.20570663700005, -7.482727000999944, 110.21817100000004, -7.473776000999976], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[110.21817100000004, -7.476926999999932, 0.0], [110.21732300000008, -7.477724999999964, 0.0], [110.21723000000009, -7.4785479999999325, 0.0], [110.21718800000008, -7.478937999999971, 0.0], [110.21718800000008, -7.47894200099995, 0.0], [110.21717700000005, -7.479108999999937, 0.0], [110.21720200000004, -7.479772999999966, 0.0], [110.21719900000005, -7.479957999999954, 0.0], [110.21719300000007, -7.479986999999937, 0.0], [110.21689600000008, -7.480677000999947, 0.0], [110.21676500000007, -7.481050000999971, 0.0], [110.21670400000005, -7.481286000999944, 0.0], [110.21593400000006, -7.481621000999951, 0.0], [110.21502100000004, -7.481777000999955, 0.0], [110.21402899900005, -7.481794998999931, 0.0], [110.21358000000004, -7.482424999999978, 0.0], [110.21356200000008, -7.4824429999999325, 0.0], [110.21328100000005, -7.482657999999958, 0.0], [110.21308000000005, -7.482727000999944, 0.0], [110.21282800000006, -7.482726000999946, 0.0], [110.21182599900004, -7.48261200099995, 0.0], [110.21156600000006, -

# %% [markdown]
# Analysis Question:
# Kelurahan mana yang memiliki jumlah KK dengan kelas tertinggi (Merah Tua)?
#
# Jawab:
# kelurahan Rejowinangun Utara
#
# Kelurahan apa saja yang tidak terdapat Sekolah Negeri?
#
# Jawab:
# 1. kramat utara
# 2. kramat selatan
# 3.potrobangsan
# 4. magelang
# 5. gelangan
# 6. cacaban
# 7. rejowinangun utara
# 8. magersari
# 9. rajowinangun selatan
# 10. tidar utara
# 11. jurongombo selatan
