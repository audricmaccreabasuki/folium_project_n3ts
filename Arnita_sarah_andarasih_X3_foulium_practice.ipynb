# %% [markdown]
# <a href="https://colab.research.google.com/github/ArnitaSarah/folium_project_n3ts/blob/main/Arnita_sarah_andarasih_X3_foulium_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Template Tugas Project
#
# 1. import folium, pandas, geopandas, dan drive.
# 2. load data shapefile, pilih kota/kabupaten yang akan dianalisis
# 3. load data csv dan proses merge/join data
# 4. load peta choropleth

# %%
# Import Library

import folium
import pandas as pd
import geopandas as gpd
from google.colab import drive

# %% [markdown]
# Pilih nama kota / kabupaten kalian. jika tidak muncul pastikan namanya sesuai dengan nama di link berikut :
# https://geoservices.big.go.id/portal/apps/webappviewer/index.html?id=cb58db080712468cb4bfd408dbde3d70
#
# ![e92f69dd74b6160e4611eee8c27905f0.png](data:image/png;base64,...)

# %%
# Read Data Shapefile

drive.mount('/content/drive')

# Shapefile Admin Indonesia (tidak usah diubah2) Warning! File besar 1.4gb
indonesia_admin = gpd.read_file('/content/drive/MyDrive/ADMIN_INDO/ADMINISTRASI_AR_DESAKEL_10K.shp')

# Pilih Kota/Kabupaten yang ingin ditampilkan, contoh 'Kota Tangerang Selatan'
aoi_admin = indonesia_admin[indonesia_admin['WADMKK'] == 'Kota Mojokerto']
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# CSV file path
csv_path = 'data mojokerto baru lgi.csv'

# Read shapefile
admin_gdf = aoi_admin

# Read CSV data
csv_data = pd.read_csv(csv_path, delimiter=';')

print(csv_data.head())
print(admin_gdf.head())
# Convert column names to lowercase
csv_data['Kelurahan'] = csv_data['Kelurahan'].str.lower().str.replace(' ', '')
admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.lower().str.replace(' ', '')
#csv_data['jumlah penduduk (jiwa)'] = csv_data['Jumlah penduduk (jiwa)'].astype(str).str.replace('.', '')
#csv_data['Jumlah penduduk (jiwa)'] = pd.to_numeric(csv_data['Jumlah penduduk (jiwa) '])

# Fix typo to merge properly
#admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.replace('Husein Sastranegara ', 'HUSEN SASTRANEGARA')
#csv_data['Kelurahan'] = csv_data['Kelurahan'].str.replace('perigibaru', 'parigibaru')

# Merge data
merged_data = pd.merge(admin_gdf, csv_data, left_on='NAMOBJ', right_on='Kelurahan', how='left')

# Convert to GeoDataFrame
merged_gdf = gpd.GeoDataFrame(merged_data, geometry=merged_data.geometry)

print(merged_gdf.head())
# Now you can use merged_gdf for further analysis and visualization
# Out:
#        Kelurahan  Jumlah KK
# 0       Mentikan       6346
# 1         Kauman       3122
# 2       Pulorejo       8560
# 3  Prajuritkulon       8121
# 4    Surodinawan       9234
#        OBJECTID          NAMOBJ       FCODE REMARK  \
# 74842   74851.0      balongsari  BA03070040   None
# 75263   75272.0          blooto  BA03070040   None
# 75909   75918.0        gedongan  BA03070040   None
# 76136   76145.0  gununggedangan  BA03070040   None
# 76187   76196.0         jagalan  BA03070040   None
#
#                                            METADATA     SRS_ID KDBBPS KDCBPS  \
# 74842  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 75263  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 75909  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 76136  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 76187  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#          KDCPUM KDEBPS  ...          WADMKK      WADMPR WIADKC WIADKK  WIADPR  \
# 74842  35.76.02   None  ...  Kota Mojokerto  Jawa Timur   None   None    None
# 75263  35.76.01   None  ...  Kota Mojokerto  Jawa Timur   None   None    None
# 75909  35.76.02   None  ...  Kota Mojokerto  Jawa Timur   None   None    None
# 76136  35.76.02   None  ...  Kota Mojokerto  Jawa Timur   None   None    None
# 76187  35.76.03   None  ...  Kota Mojokerto  Jawa Timur   None   None    None
#
#        WIADKD                             UUPP Shape_Leng Shape_Area  \
# 74842    None  Hasil Delineasi Batas Desa 2019   0.045886   0.000087
# 75263    None  Hasil Delineasi Batas Desa 2019   0.072384   0.000170
# 75909    None  Hasil Delineasi Batas Desa 2019   0.023263   0.000017
# 76136    None  Hasil Delineasi Batas Desa 2019   0.067452   0.000156
# 76187    None  Hasil Delineasi Batas Desa 2019   0.022356   0.000021
#
#                                                 geometry
# 74842  POLYGON Z ((112.44861 -7.4627 0, 112.44864 -7....
# 75263  POLYGON Z ((112.42043 -7.48041 0, 112.4203 -7....
# 75909  POLYGON Z ((112.44171 -7.46302 0, 112.44075 -7...
# 76136  POLYGON Z ((112.46151 -7.47307 0, 112.46139 -7...
# 76187  POLYGON Z ((112.43815 -7.46637 0, 112.43814 -7...
#
# [5 rows x 28 columns]
#    OBJECTID          NAMOBJ       FCODE REMARK  \
# 0   74851.0      balongsari  BA03070040   None
# 1   75272.0          blooto  BA03070040   None
# 2   75918.0        gedongan  BA03070040   None
# 3   76145.0  gununggedangan  BA03070040   None
# 4   76196.0         jagalan  BA03070040   None
#
#                                        METADATA     SRS_ID KDBBPS KDCBPS  \
# 0  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 1  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 2  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 3  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 4  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#      KDCPUM KDEBPS  ... WIADKC WIADKK WIADPR WIADKD  \
# 0  35.76.02   None  ...   None   None   None   None
# 1  35.76.01   None  ...   None   None   None   None
# 2  35.76.02   None  ...   None   None   None   None
# 3  35.76.02   None  ...   None   None   None   None
# 4  35.76.03   None  ...   None   None   None   None
#
#                               UUPP  Shape_Leng Shape_Area  \
# 0  Hasil Delineasi Batas Desa 2019    0.045886   0.000087
# 1  Hasil Delineasi Batas Desa 2019    0.072384   0.000170
# 2  Hasil Delineasi Batas Desa 2019    0.023263   0.000017
# 3  Hasil Delineasi Batas Desa 2019    0.067452   0.000156
# 4  Hasil Delineasi Batas Desa 2019    0.022356   0.000021
#
#                                             geometry       Kelurahan Jumlah KK
# 0  POLYGON Z ((112.44861 -7.4627 0, 112.44864 -7....      balongsari      7990
# 1  POLYGON Z ((112.42043 -7.48041 0, 112.4203 -7....          blooto      7180
# 2  POLYGON Z ((112.44171 -7.46302 0, 112.44075 -7...        gedongan      2264
# 3  POLYGON Z ((112.46151 -7.47307 0, 112.46139 -7...  gununggedangan      7857
# 4  POLYGON Z ((112.43815 -7.46637 0, 112.43814 -7...         jagalan      2960
#
# [5 rows x 30 columns]
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Create a base map
m = folium.Map(location=[-7.4701965884827715, 112.44050578689622], zoom_start=11)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name='choropleth',
    data=merged_gdf,
    columns=["Kelurahan", "Jumlah KK"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="Jumlah Penduduk"
).add_to(m)

jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='Jumlah KK',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['WADMKD','Jumlah KK'],
        aliases=['Kelurahan','Jumlah Penduduk']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8701a764b622349917c586573363c22e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8701a764b622349917c586573363c22e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8701a764b622349917c586573363c22e = L.map(
#                 &quot;map_8701a764b622349917c586573363c22e&quot;,
#                 {
#                     center: [-7.4701965884827715, 112.44050578689622],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11e9da456b616e6e27a73cf7aea68fc8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_11e9da456b616e6e27a73cf7aea68fc8.addTo(map_8701a764b622349917c586573363c22e);
#
#
#             var choropleth_17441448986cd25f3a477190193cfae1 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_624af8d260a0f605d18093f46567cee8_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;3&quot;: case &quot;8&quot;: case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;14&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_624af8d260a0f605d18093f46567cee8_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_624af8d260a0f605d18093f46567cee8 = L.geoJson(null, {
#                 onEachFeature: geo_json_624af8d260a0f605d18093f46567cee8_onEachFeature,
#
#                 style: geo_json_624af8d260a0f605d18093f46567cee8_styler,
#         });
#
#         function geo_json_624af8d260a0f605d18093f46567cee8_add (data) {
#             geo_json_624af8d260a0f605d18093f46567cee8
#                 .addData(data);
#         }
#             geo_json_624af8d260a0f605d18093f46567cee8_add({&quot;bbox&quot;: [112.4057936910001, -7.494623840999964, 112.46865202300012, -7.447384434999947], &quot;features&quot;: [{&quot;bbox&quot;: [112.43748000000005, -7.474506041999973, 112.4486388470001, -7.462517840999965], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[112.44861010200009, -7.462695769999925, 0.0], [112.4486388470001, -7.462757453999927, 0.0], [112.44863289800003, -7.46293888699995, 0.0], [112.44860018100007, -7.463346368999964, 0.0], [112.44858233500008, -7.46369139199993, 0.0], [112.4485555660001, -7.464214872999946, 0.0], [112.44854961700003, -7.46479784099995, 0.0], [112.44853177100003, -7.465258860999938, 0.0], [112.44850797700008, -7.46530050299998, 0.0], [112.44833249200008, -7.465386756999976, 0.0], [112.44828000000007, -7.465409999999963, 0.0], [112.44826, -7.465590000999953, 0.0], [112.44825000000003, -7.46571999899993, 0.0], [112.4482700000001, -7.466519998999956, 0.0], [112.4482700000001, -7.46658999999994, 0.0], [112.44826, -7.466700000999936, 0.0],

# %%
# Create a base map
m = folium.Map(location=[-7.4701965884827715, 112.44050578689622], zoom_start=13)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name='choropleth',
    data=merged_gdf,
    columns=["Kelurahan", "Jumlah KK"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="Jumlah Penduduk"
).add_to(m)

# Create/import data sma
data_sma = pd.read_csv('SMA MOJOKERTO.csv')

data_sma['geometry'] = gpd.GeoSeries.from_wkt(data_sma['WKT'])

# Extract latitude and longitude from Point geometries
data_sma['latitude'] = data_sma['geometry'].apply(lambda x: x.y)
data_sma['longitude'] = data_sma['geometry'].apply(lambda x: x.x)

# Add markers to the map
# Create a marker layer
marker_layer = folium.FeatureGroup(name="SMAN MOJOKERTO")

# Add markers to the layer
for i in range(0, len(data_sma)):
    folium.Marker([data_sma.iloc[i]['latitude'], data_sma.iloc[i]['longitude']], popup=data_sma.iloc[i]['nama']).add_to(marker_layer)

m.add_child(marker_layer)

# Add Jumlah_KK layer map
jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='Jumlah KK',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['WADMKD','Jumlah KK'],
        aliases=['Kelurahan','Jumlah KK']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8bf44deee4765c3fb9c248e5e8fff3f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8bf44deee4765c3fb9c248e5e8fff3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8bf44deee4765c3fb9c248e5e8fff3f = L.map(
#                 &quot;map_d8bf44deee4765c3fb9c248e5e8fff3f&quot;,
#                 {
#                     center: [-7.4701965884827715, 112.44050578689622],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0479ab5afbc3cd0718bfc249b0229878 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0479ab5afbc3cd0718bfc249b0229878.addTo(map_d8bf44deee4765c3fb9c248e5e8fff3f);
#
#
#             var choropleth_8e9105cdaa6367b7cf34af94eb37453e = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_62bef9d34ae3015fc5997667f2767fa7_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;3&quot;: case &quot;8&quot;: case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;14&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_62bef9d34ae3015fc5997667f2767fa7_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_62bef9d34ae3015fc5997667f2767fa7 = L.geoJson(null, {
#                 onEachFeature: geo_json_62bef9d34ae3015fc5997667f2767fa7_onEachFeature,
#
#                 style: geo_json_62bef9d34ae3015fc5997667f2767fa7_styler,
#         });
#
#         function geo_json_62bef9d34ae3015fc5997667f2767fa7_add (data) {
#             geo_json_62bef9d34ae3015fc5997667f2767fa7
#                 .addData(data);
#         }
#             geo_json_62bef9d34ae3015fc5997667f2767fa7_add({&quot;bbox&quot;: [112.4057936910001, -7.494623840999964, 112.46865202300012, -7.447384434999947], &quot;features&quot;: [{&quot;bbox&quot;: [112.43748000000005, -7.474506041999973, 112.4486388470001, -7.462517840999965], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[112.44861010200009, -7.462695769999925, 0.0], [112.4486388470001, -7.462757453999927, 0.0], [112.44863289800003, -7.46293888699995, 0.0], [112.44860018100007, -7.463346368999964, 0.0], [112.44858233500008, -7.46369139199993, 0.0], [112.4485555660001, -7.464214872999946, 0.0], [112.44854961700003, -7.46479784099995, 0.0], [112.44853177100003, -7.465258860999938, 0.0], [112.44850797700008, -7.46530050299998, 0.0], [112.44833249200008, -7.465386756999976, 0.0], [112.44828000000007, -7.465409999999963, 0.0], [112.44826, -7.465590000999953, 0.0], [112.44825000000003, -7.46571999899993, 0.0], [112.4482700000001, -7.466519998999956, 0.0], [112.4482700000001, -7.46658999999994, 0.0], [112.44826, -7.466700000999936, 0.0],

# %% [markdown]
# Analysis Question:
# Kelurahan mana yang memiliki jumlah KK dengan kelas tertinggi (Merah Tua)?
#
# Jawab: kelurahan wates
#
# Kelurahan apa saja yang tidak terdapat Sekolah Negeri?
#
# Jawab:
# 1. pulorejo
# 2. mentikan
# 3. blooto
# 4. prajurit kulon
# 5. jagalan
# 6. meri
# 7. kedundung
# 8. kedongan
# 9. miji
# 10. gununggedangan
# 11. sentanan
# 12. magersari
