# %% [markdown]
# <a href="https://colab.research.google.com/github/ilonazizi/folium_project_n3ts/blob/main/Ilona_zizi_kalista_X_5_Kota_Bukittinggi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Template Tugas Project
#
# 1. import folium, pandas, geopandas, dan drive.
# 2. load data shapefile, pilih kota/kabupaten yang akan dianalisis
# 3. load data csv dan proses merge/join data
# 4. load peta choropleth

# %%
# Import Library

import folium
import pandas as pd
import geopandas as gpd
from google.colab import drive

# %% [markdown]
# Pilih nama kota / kabupaten kalian. jika tidak muncul pastikan namanya sesuai dengan nama di link berikut :
# https://geoservices.big.go.id/portal/apps/webappviewer/index.html?id=cb58db080712468cb4bfd408dbde3d70
#
# ![e92f69dd74b6160e4611eee8c27905f0.png](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Read Data Shapefile

drive.mount('/content/drive')

# Shapefile Admin Indonesia (tidak usah diubah2) Warning! File besar 1.4gb
indonesia_admin = gpd.read_file('/content/drive/MyDrive/ADMIN_INDO/ADMINISTRASI_AR_DESAKEL_10K.shp')

# Pilih Kota/Kabupaten yang ingin ditampilkan, contoh 'Kota Tangerang Selatan'
aoi_admin = indonesia_admin[indonesia_admin['WADMKK'] == 'Kota Bukittinggi']
# Out:
# Mounted at /content/drive

# %%
# CSV file path
csv_path = '/content/data_bukttimggi.csv'

# Read shapefile
admin_gdf = aoi_admin

# Read CSV data
csv_data = pd.read_csv(csv_path, delimiter=';')

print(csv_data.head())
print(admin_gdf.head())
# Convert column names to lowercase
csv_data['Kelurahan'] = csv_data['Kelurahan'].str.lower().str.replace(' ', '')
admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.lower().str.replace(' ', '')
#csv_data['Jumlah_KK'] = csv_data['Jumlah_KK'].astype(str).str.replace('.', '')
#csv_data['Jumlah_KK'] = pd.to_numeric(csv_data['Jumlah_KK'])

# Fix typo to merge properly
#admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.replace('pondokjagungt', 'pondokjagung')
csv_data['Kelurahan'] = csv_data['Kelurahan'].str.replace('bukitapitpuhun', 'bukikapikpuhun')

# Merge data
merged_data = pd.merge(admin_gdf, csv_data, left_on='NAMOBJ', right_on='Kelurahan', how='left')

# Convert to GeoDataFrame
merged_gdf = gpd.GeoDataFrame(merged_data, geometry=merged_data.geometry)

print(merged_gdf.head())
# Now you can use merged_gdf for further analysis and visualization
# Out:
#                      Kelurahan  Penduduk
# 0    Bukit Cangang Kayu Ramang      6063
# 1                   Tarok Dipo     13665
# 2                  Pakan Kurai      8412
# 3  Aur Tajungkang Tangah Sawah     12776
# 4           Benteng Pasar Atas      2719
#        OBJECTID                    NAMOBJ       FCODE REMARK  \
# 40096   40097.0                 aurkuning  BA03070040   None
# 40099   40100.0  aurtajungkangtangahsawah  BA03070040   None
# 40288   40289.0             belakangbalok  BA03070040   None
# 40309   40310.0          bentengpasaratas  BA03070040   None
# 40340   40341.0                    birugo  BA03070040   None
#
#                                            METADATA     SRS_ID KDBBPS KDCBPS  \
# 40096  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 40099  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 40288  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 40309  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 40340  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#          KDCPUM KDEBPS  ...            WADMKK          WADMPR WIADKC WIADKK  \
# 40096  13.75.03   None  ...  Kota Bukittinggi  Sumatera Barat   None   None
# 40099  13.75.01   None  ...  Kota Bukittinggi  Sumatera Barat   None   None
# 40288  13.75.03   None  ...  Kota Bukittinggi  Sumatera Barat   None   None
# 40309  13.75.01   None  ...  Kota Bukittinggi  Sumatera Barat   None   None
# 40340  13.75.03   None  ...  Kota Bukittinggi  Sumatera Barat   None   None
#
#        WIADPR  WIADKD                             UUPP Shape_Leng Shape_Area  \
# 40096    None    None  Hasil Delineasi Batas Desa 2019   0.046695   0.000077
# 40099    None    None  Hasil Delineasi Batas Desa 2019   0.040416   0.000040
# 40288    None    None  Hasil Delineasi Batas Desa 2019   0.030327   0.000038
# 40309    None    None  Hasil Delineasi Batas Desa 2019   0.024265   0.000021
# 40340    None    None  Hasil Delineasi Batas Desa 2019   0.045715   0.000062
#
#                                                 geometry
# 40096  POLYGON Z ((100.38904 -0.31755 0, 100.38903 -0...
# 40099  POLYGON Z ((100.37169 -0.29974 0, 100.37169 -0...
# 40288  POLYGON Z ((100.37201 -0.31241 0, 100.37186 -0...
# 40309  POLYGON Z ((100.36854 -0.29933 0, 100.3687 -0....
# 40340  POLYGON Z ((100.38127 -0.31436 0, 100.38125 -0...
#
# [5 rows x 28 columns]
#    OBJECTID                    NAMOBJ       FCODE REMARK  \
# 0   40097.0                 aurkuning  BA03070040   None
# 1   40100.0  aurtajungkangtangahsawah  BA03070040   None
# 2   40289.0             belakangbalok  BA03070040   None
# 3   40310.0          bentengpasaratas  BA03070040   None
# 4   40341.0                    birugo  BA03070040   None
#
#                                        METADATA     SRS_ID KDBBPS KDCBPS  \
# 0  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 1  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 2  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 3  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 4  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#      KDCPUM KDEBPS  ... WIADKC WIADKK WIADPR WIADKD  \
# 0  13.75.03   None  ...   None   None   None   None
# 1  13.75.01   None  ...   None   None   None   None
# 2  13.75.03   None  ...   None   None   None   None
# 3  13.75.01   None  ...   None   None   None   None
# 4  13.75.03   None  ...   None   None   None   None
#
#                               UUPP  Shape_Leng Shape_Area  \
# 0  Hasil Delineasi Batas Desa 2019    0.046695   0.000077
# 1  Hasil Delineasi Batas Desa 2019    0.040416   0.000040
# 2  Hasil Delineasi Batas Desa 2019    0.030327   0.000038
# 3  Hasil Delineasi Batas Desa 2019    0.024265   0.000021
# 4  Hasil Delineasi Batas Desa 2019    0.045715   0.000062
#
#                                             geometry  \
# 0  POLYGON Z ((100.38904 -0.31755 0, 100.38903 -0...
# 1  POLYGON Z ((100.37169 -0.29974 0, 100.37169 -0...
# 2  POLYGON Z ((100.37201 -0.31241 0, 100.37186 -0...
# 3  POLYGON Z ((100.36854 -0.29933 0, 100.3687 -0....
# 4  POLYGON Z ((100.38127 -0.31436 0, 100.38125 -0...
#
#                   Kelurahan Penduduk
# 0                 aurkuning     8829
# 1  aurtajungkangtangahsawah    12776
# 2             belakangbalok     6949
# 3          bentengpasaratas     2719
# 4                    birugo     7617
#
# [5 rows x 30 columns]
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Create a base map
m = folium.Map(location=[-0.304377, 100.379642], zoom_start=11)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name='choropleth',
    data=merged_gdf,
    columns=["Kelurahan", "Penduduk"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="Penduduk"
).add_to(m)

jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='Penduduk',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['WADMKD','Penduduk'],
        aliases=['Kelurahan','Penduduk']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a7f0872536f0f3e9c2b8c713b657bd43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a7f0872536f0f3e9c2b8c713b657bd43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a7f0872536f0f3e9c2b8c713b657bd43 = L.map(
#                 &quot;map_a7f0872536f0f3e9c2b8c713b657bd43&quot;,
#                 {
#                     center: [-0.304377, 100.379642],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be2e0f5795d2db144128eef3a166fcca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_be2e0f5795d2db144128eef3a166fcca.addTo(map_a7f0872536f0f3e9c2b8c713b657bd43);
#
#
#             var choropleth_4cabf7f2e568b026d07c3b5dde7e5bf9 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_7d88e18a7d00433e83d1dc435d2b0ea3_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;16&quot;: case &quot;20&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;22&quot;: case &quot;23&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;4&quot;: case &quot;8&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;5&quot;: case &quot;9&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;19&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_7d88e18a7d00433e83d1dc435d2b0ea3_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7d88e18a7d00433e83d1dc435d2b0ea3 = L.geoJson(null, {
#                 onEachFeature: geo_json_7d88e18a7d00433e83d1dc435d2b0ea3_onEachFeature,
#
#                 style: geo_json_7d88e18a7d00433e83d1dc435d2b0ea3_styler,
#         });
#
#         function geo_json_7d88e18a7d00433e83d1dc435d2b0ea3_add (data) {
#             geo_json_7d88e18a7d00433e83d1dc435d2b0ea3
#                 .addData(data);
#         }
#             geo_json_7d88e18a7d00433e83d1dc435d2b0ea3_add({&quot;bbox&quot;: [100.33263301200009, -0.32553224199995157, 100.40785635000003, -0.27107085399995867], &quot;features&quot;: [{&quot;bbox&quot;: [100.38001363800004, -0.3255054839999616, 100.39069396900004, -0.31427489899994043], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.38904014000008, -0.31755458399993586, 0.0], [100.38902815500006, -0.317585668999925, 0.0], [100.38901369100006, -0.3176231769999731, 0.0], [100.38899573900005, -0.31766973699996015, 0.0], [100.38897204500006, -0.3177790899999309, 0.0], [100.38896680200008, -0.31779008299997713, 0.0], [100.38886998500004, -0.3179931179999471, 0.0], [100.38885640000007, -0.318053908999957, 0.0], [100.38885960000005, -0.31808087099994964, 0.0], [100.38886312800008, -0.3181105999999545, 0.0], [100.38893521500006, -0.31822372899995344, 0.0], [100.38892458500004, -0.31834398799992414, 0.0], [100.38891886100004, -0.31840924499994117, 0.0], [100.38890831900005, -0.3185294599999793, 0.0], [100.38893131800006, -0.31857726699996647, 0.0], [100.38894351600004, -0.3185951469999395, 0.0], [100.38896233600008, -0.31862272899996924, 0.0], [100.38899016700003, -0.31866354399994634, 0.0], [

# %%
# Create a base map
m = folium.Map(location=[-0.304377, 100.379642], zoom_start=13)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name="Penduduk",
    data=merged_gdf,
    columns=["Kelurahan", "Penduduk"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="Penduduk"
).add_to(m)

# Create/import data sma
data_sma = pd.read_csv('SMAN Bukittinggi.csv')

data_sma['geometry'] = gpd.GeoSeries.from_wkt(data_sma['WKT'])

# Extract latitude and longitude from Point geometries
data_sma['latitude'] = data_sma['geometry'].apply(lambda x: x.y)
data_sma['longitude'] = data_sma['geometry'].apply(lambda x: x.x)

# Add markers to the map
# Create a marker layer
marker_layer = folium.FeatureGroup(name="SMAN Bukittinggi")

# Add markers to the layer
for i in range(0, len(data_sma)):
    folium.Marker([data_sma.iloc[i]['latitude'], data_sma.iloc[i]['longitude']], popup=data_sma.iloc[i]['nama']).add_to(marker_layer)

m.add_child(marker_layer)

# Add Jumlah_KK layer map
jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='Penduduk',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['NAMOBJ','Penduduk'],
        aliases=['Kelurahan','Penduduk']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df99da3752cc5e2027702b8b6a63c8cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df99da3752cc5e2027702b8b6a63c8cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df99da3752cc5e2027702b8b6a63c8cb = L.map(
#                 &quot;map_df99da3752cc5e2027702b8b6a63c8cb&quot;,
#                 {
#                     center: [-0.304377, 100.379642],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19991f618b28f2737c32190491f252e9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_19991f618b28f2737c32190491f252e9.addTo(map_df99da3752cc5e2027702b8b6a63c8cb);
#
#
#             var choropleth_d06c602f19be6099d0622957b11391d0 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_5664fe575e3fd6199e59fdd99b8f4a5c_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;16&quot;: case &quot;20&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;22&quot;: case &quot;23&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;4&quot;: case &quot;8&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;5&quot;: case &quot;9&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;19&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_5664fe575e3fd6199e59fdd99b8f4a5c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5664fe575e3fd6199e59fdd99b8f4a5c = L.geoJson(null, {
#                 onEachFeature: geo_json_5664fe575e3fd6199e59fdd99b8f4a5c_onEachFeature,
#
#                 style: geo_json_5664fe575e3fd6199e59fdd99b8f4a5c_styler,
#         });
#
#         function geo_json_5664fe575e3fd6199e59fdd99b8f4a5c_add (data) {
#             geo_json_5664fe575e3fd6199e59fdd99b8f4a5c
#                 .addData(data);
#         }
#             geo_json_5664fe575e3fd6199e59fdd99b8f4a5c_add({&quot;bbox&quot;: [100.33263301200009, -0.32553224199995157, 100.40785635000003, -0.27107085399995867], &quot;features&quot;: [{&quot;bbox&quot;: [100.38001363800004, -0.3255054839999616, 100.39069396900004, -0.31427489899994043], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.38904014000008, -0.31755458399993586, 0.0], [100.38902815500006, -0.317585668999925, 0.0], [100.38901369100006, -0.3176231769999731, 0.0], [100.38899573900005, -0.31766973699996015, 0.0], [100.38897204500006, -0.3177790899999309, 0.0], [100.38896680200008, -0.31779008299997713, 0.0], [100.38886998500004, -0.3179931179999471, 0.0], [100.38885640000007, -0.318053908999957, 0.0], [100.38885960000005, -0.31808087099994964, 0.0], [100.38886312800008, -0.3181105999999545, 0.0], [100.38893521500006, -0.31822372899995344, 0.0], [100.38892458500004, -0.31834398799992414, 0.0], [100.38891886100004, -0.31840924499994117, 0.0], [100.38890831900005, -0.3185294599999793, 0.0], [100.38893131800006, -0.31857726699996647, 0.0], [100.38894351600004, -0.3185951469999395, 0.0], [100.38896233600008, -0.31862272899996924, 0.0], [100.38899016700003, -0.31866354399994634, 0.0], [

# %% [markdown]
# Analysis Question:
# Kelurahan mana yang memiliki Penduduk dengan kelas tertinggi (Merah Tua)?
#
# Jawab:tarokdipo
#
# Kelurahan apa saja yang tidak terdapat Sekolah Negeri?
#
# Jawab:birugo, aurkuning, pakanlabuah, belakangbalok, bukitcangangkayuramang, kubutanjung, bukikapikpuhun, paritantang, pulaianakair, 	aurtajungkangtangahsawah, 	manggisganting, garegeh, puhuntembok, kubugulaibancah
