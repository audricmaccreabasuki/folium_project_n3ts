# %% [markdown]
# <a href="https://colab.research.google.com/github/nadzivamutiara/folium_project_n3ts/blob/main/Nadziva_Mutiara_X_3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Template Tugas Project
#
# 1. import folium, pandas, geopandas, dan drive.
# 2. load data shapefile, pilih kota/kabupaten yang akan dianalisis
# 3. load data csv dan proses merge/join data
# 4. load peta choropleth

# %%
# Import Library

import folium
import pandas as pd
import geopandas as gpd
from google.colab import drive

# %% [markdown]
# Pilih nama kota / kabupaten kalian. jika tidak muncul pastikan namanya sesuai dengan nama di link berikut :
# https://geoservices.big.go.id/portal/apps/webappviewer/index.html?id=cb58db080712468cb4bfd408dbde3d70
#
# ![e92f69dd74b6160e4611eee8c27905f0.png](data:image/png;base64,...)

# %%
# Read Data Shapefile

drive.mount('/content/drive')

# Shapefile Admin Indonesia (tidak usah diubah2) Warning! File besar 1.4gb
indonesia_admin = gpd.read_file('/content/drive/MyDrive/ADMIN_INDO/ADMINISTRASI_AR_DESAKEL_10K.shp')

# Pilih Kota/Kabupaten yang ingin ditampilkan, contoh 'Kota Tangerang Selatan'
aoi_admin = indonesia_admin[indonesia_admin['WADMKK'] == 'Kota Padang Panjang']
# Out:
# Mounted at /content/drive

# %%
# CSV file path
csv_path = '/content/drive/MyDrive/KK_PPANJANG.csv'

# Read shapefile
admin_gdf = aoi_admin

# Read CSV data
csv_data = pd.read_csv(csv_path)

print(csv_data.head())
print(admin_gdf.head())
# Convert column names to lowercase
csv_data['Kelurahan'] = csv_data['Kelurahan'].str.lower().str.replace(' ', '')
admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.lower().str.replace(' ', '')
#csv_data['Jumlah_KK'] = csv_data['Jumlah_KK'].astype(str).str.replace('.', '')
#csv_data['Jumlah_KK'] = pd.to_numeric(csv_data['Jumlah_KK'])

# Fix typo to merge properly
#admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.replace('pondokjagungt', 'pondokjagung')
#csv_data['Kelurahan'] = csv_data['Kelurahan'].str.replace('perigibaru', 'parigibaru')

# Merge data
merged_data = pd.merge(admin_gdf, csv_data, left_on='NAMOBJ', right_on='Kelurahan', how='left')

# Convert to GeoDataFrame
merged_gdf = gpd.GeoDataFrame(merged_data, geometry=merged_data.geometry)

print(merged_gdf.head())
# Now you can use merged_gdf for further analysis and visualization
# Out:
#          Kelurahan  Unnamed: 1  Jumlah_KK  Tahun
# 0    Silaing Bawah         NaN       3084   2020
# 1     Silaing Atas         NaN       1070   2020
# 2      Pasar Usang         NaN       1916   2020
# 3  Kampung Manggis         NaN       3522   2020
# 4      Tanah Hitam         NaN       1827   2020
#        OBJECTID           NAMOBJ       FCODE REMARK  \
# 40132   40133.0      Balai-Balai  BA03070040   None
# 40510   40511.0       Ekor Lubuk  BA03070040   None
# 40560   40561.0  Guguk Malintang  BA03070040   None
# 40705   40706.0  Kampung Manggis  BA03070040   None
# 40884   40885.0       Koto Katik  BA03070040   None
#
#                                            METADATA     SRS_ID KDBBPS KDCBPS  \
# 40132  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 40510  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 40560  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 40705  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 40884  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#          KDCPUM KDEBPS  ...               WADMKK          WADMPR WIADKC  \
# 40132  13.74.02   None  ...  Kota Padang Panjang  Sumatera Barat   None
# 40510  13.74.01   None  ...  Kota Padang Panjang  Sumatera Barat   None
# 40560  13.74.01   None  ...  Kota Padang Panjang  Sumatera Barat   None
# 40705  13.74.02   None  ...  Kota Padang Panjang  Sumatera Barat   None
# 40884  13.74.01   None  ...  Kota Padang Panjang  Sumatera Barat   None
#
#       WIADKK  WIADPR  WIADKD                             UUPP Shape_Leng  \
# 40132   None    None    None  Hasil Delineasi Batas Desa 2019   0.027230
# 40510   None    None    None  Hasil Delineasi Batas Desa 2019   0.062625
# 40560   None    None    None  Hasil Delineasi Batas Desa 2019   0.067516
# 40705   None    None    None  Hasil Delineasi Batas Desa 2019   0.105006
# 40884   None    None    None  Hasil Delineasi Batas Desa 2019   0.070966
#
#       Shape_Area                                           geometry
# 40132   0.000031  POLYGON Z ((100.40456 -0.4645 0, 100.40457 -0....
# 40510   0.000127  POLYGON Z ((100.43609 -0.47152 0, 100.4361 -0....
# 40560   0.000083  POLYGON Z ((100.40866 -0.45931 0, 100.40866 -0...
# 40705   0.000400  POLYGON Z ((100.39477 -0.46324 0, 100.39518 -0...
# 40884   0.000176  POLYGON Z ((100.41725 -0.47846 0, 100.41724 -0...
#
# [5 rows x 28 columns]
#    OBJECTID          NAMOBJ       FCODE REMARK  \
# 0   40133.0     balai-balai  BA03070040   None
# 1   40511.0       ekorlubuk  BA03070040   None
# 2   40561.0  gugukmalintang  BA03070040   None
# 3   40706.0  kampungmanggis  BA03070040   None
# 4   40885.0       kotokatik  BA03070040   None
#
#                                        METADATA     SRS_ID KDBBPS KDCBPS  \
# 0  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 1  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 2  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 3  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 4  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#      KDCPUM KDEBPS  ... WIADPR WIADKD                             UUPP  \
# 0  13.74.02   None  ...   None   None  Hasil Delineasi Batas Desa 2019
# 1  13.74.01   None  ...   None   None  Hasil Delineasi Batas Desa 2019
# 2  13.74.01   None  ...   None   None  Hasil Delineasi Batas Desa 2019
# 3  13.74.02   None  ...   None   None  Hasil Delineasi Batas Desa 2019
# 4  13.74.01   None  ...   None   None  Hasil Delineasi Batas Desa 2019
#
#   Shape_Leng  Shape_Area                                           geometry  \
# 0   0.027230    0.000031  POLYGON Z ((100.40456 -0.4645 0, 100.40457 -0....
# 1   0.062625    0.000127  POLYGON Z ((100.43609 -0.47152 0, 100.4361 -0....
# 2   0.067516    0.000083  POLYGON Z ((100.40866 -0.45931 0, 100.40866 -0...
# 3   0.105006    0.000400  POLYGON Z ((100.39477 -0.46324 0, 100.39518 -0...
# 4   0.070966    0.000176  POLYGON Z ((100.41725 -0.47846 0, 100.41724 -0...
#
#         Kelurahan Unnamed: 1 Jumlah_KK Tahun
# 0     balai-balai        NaN      2790  2020
# 1       ekorlubuk        NaN      1200  2020
# 2  gugukmalintang        NaN      3053  2020
# 3  kampungmanggis        NaN      3522  2020
# 4       kotokatik        NaN       577  2020
#
# [5 rows x 32 columns]
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Create a base map
m = folium.Map(location=[-0.4693578,100.2536745], zoom_start=11)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name='choropleth',
    data=merged_gdf,
    columns=["Kelurahan", "Jumlah_KK"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="Jumlah_KK"
).add_to(m)

jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='Jumlah_KK',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['WADMKD','Jumlah_KK'],
        aliases=['Kelurahan','Jumlah_KK']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e32123e2182ed3b7bbda4716e699875 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e32123e2182ed3b7bbda4716e699875&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e32123e2182ed3b7bbda4716e699875 = L.map(
#                 &quot;map_5e32123e2182ed3b7bbda4716e699875&quot;,
#                 {
#                     center: [-0.4693578, 100.2536745],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c10f2d1952f248308c6e10387a0210a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8c10f2d1952f248308c6e10387a0210a.addTo(map_5e32123e2182ed3b7bbda4716e699875);
#
#
#             var choropleth_e68199b3b7995d4c750f8648ac06304e = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_eb2e0bf000fad4d57a31730187658c84_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;6&quot;: case &quot;10&quot;: case &quot;14&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;3&quot;: case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;4&quot;: case &quot;7&quot;: case &quot;9&quot;: case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_eb2e0bf000fad4d57a31730187658c84_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_eb2e0bf000fad4d57a31730187658c84 = L.geoJson(null, {
#                 onEachFeature: geo_json_eb2e0bf000fad4d57a31730187658c84_onEachFeature,
#
#                 style: geo_json_eb2e0bf000fad4d57a31730187658c84_styler,
#         });
#
#         function geo_json_eb2e0bf000fad4d57a31730187658c84_add (data) {
#             geo_json_eb2e0bf000fad4d57a31730187658c84
#                 .addData(data);
#         }
#             geo_json_eb2e0bf000fad4d57a31730187658c84_add({&quot;bbox&quot;: [100.36533772700005, -0.4914661789999286, 100.43749634400007, -0.4492322689999355], &quot;features&quot;: [{&quot;bbox&quot;: [100.39977069600008, -0.46985696299992696, 100.40529138200009, -0.4610091049999596], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.40455539900006, -0.46450220299993816, 0.0], [100.40457388400006, -0.4645944839999743, 0.0], [100.40457133000007, -0.46459684099994547, 0.0], [100.40457091100006, -0.4646388589999333, 0.0], [100.40456941600007, -0.4647893729999737, 0.0], [100.40456674300003, -0.46505831499996475, 0.0], [100.40457043700007, -0.465246380999929, 0.0], [100.40457060700004, -0.46525502099996174, 0.0], [100.40457147800004, -0.46529930499997363, 0.0], [100.40457414200006, -0.46543490799996334, 0.0], [100.40457565100007, -0.4655117159999804, 0.0], [100.40457790000005, -0.465626216999965, 0.0], [100.40457852500003, -0.46565804599993044, 0.0], [100.40457904400006, -0.4656837959999507, 0.0], [100.40457907200005, -0.465685189999931, 0.0], [100.40457945800006, -0.465705532999948, 0.0], [100.40458519900005, -0.

# %%
# Create a base map
m = folium.Map(location=[-0.4693578,100.2536745], zoom_start=11)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name="Jumlah KK Kelurahan Padang Panjang",
    data=merged_gdf,
    columns=["Kelurahan", "Jumlah_KK"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="Jumlah_KK"
).add_to(m)

# Create/import data sma
# The original path 'content/drive/MyDrive/padangpanjang.csv' likely has a typo
# or the file is not present.
# Make sure the path is correct and the file exists in your Google Drive.
# Assuming the file is in '/content/drive/MyDrive/padangpanjang.csv',
# we change the path accordingly.
data_sma = pd.read_csv('/content/drive/MyDrive/padangpanjang.csv')

data_sma['geometry'] = gpd.GeoSeries.from_wkt(data_sma['WKT'])

# Extract latitude and longitude from Point geometries
data_sma['latitude'] = data_sma['geometry'].apply(lambda x: x.y)
data_sma['longitude'] = data_sma['geometry'].apply(lambda x: x.x)

# Add markers to the map
# Create a marker layer
marker_layer = folium.FeatureGroup(name="SMAN Padang Panjang")

# Add markers to the layer
for i in range(0, len(data_sma)):
    folium.Marker([data_sma.iloc[i]['latitude'], data_sma.iloc[i]['longitude']], popup=data_sma.iloc[i]['nama']).add_to(marker_layer)

m.add_child(marker_layer)

# Add Jumlah_KK layer map
jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='Jumlah_KK',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['NAMOBJ','Jumlah_KK'],
        aliases=['Kelurahan','Jumlah_KK']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e7f477ffc61a779d74774cb2f4f5d38 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e7f477ffc61a779d74774cb2f4f5d38&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e7f477ffc61a779d74774cb2f4f5d38 = L.map(
#                 &quot;map_7e7f477ffc61a779d74774cb2f4f5d38&quot;,
#                 {
#                     center: [-0.4693578, 100.2536745],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14299004031bd89526d229097f1ff023 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_14299004031bd89526d229097f1ff023.addTo(map_7e7f477ffc61a779d74774cb2f4f5d38);
#
#
#             var choropleth_e2bf5c6c240cd042c997b63a3b0162e4 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_ae314cd2cafa84cf5629d8b30c1b2aac_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;6&quot;: case &quot;10&quot;: case &quot;14&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;3&quot;: case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;4&quot;: case &quot;7&quot;: case &quot;9&quot;: case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ae314cd2cafa84cf5629d8b30c1b2aac_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ae314cd2cafa84cf5629d8b30c1b2aac = L.geoJson(null, {
#                 onEachFeature: geo_json_ae314cd2cafa84cf5629d8b30c1b2aac_onEachFeature,
#
#                 style: geo_json_ae314cd2cafa84cf5629d8b30c1b2aac_styler,
#         });
#
#         function geo_json_ae314cd2cafa84cf5629d8b30c1b2aac_add (data) {
#             geo_json_ae314cd2cafa84cf5629d8b30c1b2aac
#                 .addData(data);
#         }
#             geo_json_ae314cd2cafa84cf5629d8b30c1b2aac_add({&quot;bbox&quot;: [100.36533772700005, -0.4914661789999286, 100.43749634400007, -0.4492322689999355], &quot;features&quot;: [{&quot;bbox&quot;: [100.39977069600008, -0.46985696299992696, 100.40529138200009, -0.4610091049999596], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[100.40455539900006, -0.46450220299993816, 0.0], [100.40457388400006, -0.4645944839999743, 0.0], [100.40457133000007, -0.46459684099994547, 0.0], [100.40457091100006, -0.4646388589999333, 0.0], [100.40456941600007, -0.4647893729999737, 0.0], [100.40456674300003, -0.46505831499996475, 0.0], [100.40457043700007, -0.465246380999929, 0.0], [100.40457060700004, -0.46525502099996174, 0.0], [100.40457147800004, -0.46529930499997363, 0.0], [100.40457414200006, -0.46543490799996334, 0.0], [100.40457565100007, -0.4655117159999804, 0.0], [100.40457790000005, -0.465626216999965, 0.0], [100.40457852500003, -0.46565804599993044, 0.0], [100.40457904400006, -0.4656837959999507, 0.0], [100.40457907200005, -0.465685189999931, 0.0], [100.40457945800006, -0.465705532999948, 0.0], [100.40458519900005, -0.

# %% [markdown]
# Analysis Question:
# Kelurahan mana yang memiliki jumlah KK dengan kelas tertinggi (Merah Tua)?
#
# Jawab:silaingbawah, kampungmanggis, gugukmalintang,
#
# Kelurahan apa saja yang tidak terdapat Sekolah Negeri?
#
# Jawab: balai-balai, bukitsurungan, pasarusang ,kampungmanggis, tanahhitam, silaingatas, kotopanjang, kotokatik, ngalau, 	ekorlubuk, ganting, tanahpaklambik, 	pasarusang
