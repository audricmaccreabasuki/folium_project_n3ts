# %% [markdown]
# <a href="https://colab.research.google.com/github/junaaaww/folium_project_n3ts/blob/main/Arjuna_Wahyu_Pamungkas_X5_Kota_Cirebon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Template Tugas Project
#
# 1. import folium, pandas, geopandas, dan drive.
# 2. load data shapefile, pilih kota/kabupaten yang akan dianalisis
# 3. load data csv dan proses merge/join data
# 4. load peta choropleth

# %%
# Import Library

import folium
import pandas as pd
import geopandas as gpd
from google.colab import drive

# %% [markdown]
# Pilih nama kota / kabupaten kalian. jika tidak muncul pastikan namanya sesuai dengan nama di link berikut :
# https://geoservices.big.go.id/portal/apps/webappviewer/index.html?id=cb58db080712468cb4bfd408dbde3d70
#
# ![e92f69dd74b6160e4611eee8c27905f0.png](data:image/png;base64,...)

# %%
# Read Data Shapefile

drive.mount('/content/drive')

# Shapefile Admin Indonesia (tidak usah diubah2) Warning! File besar 1.4gb
indonesia_admin = gpd.read_file('/content/drive/MyDrive/ADMIN_INDO/ADMINISTRASI_AR_DESAKEL_10K.shp')

# Pilih Kota/Kabupaten yang ingin ditampilkan, contoh 'Kota Tangerang Selatan'
aoi_admin = indonesia_admin[indonesia_admin['WADMKK'] == 'Kota Cirebon']
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# CSV file path
csv_path = '/content/drive/MyDrive/Penduduk Kelurahan, 2016-2018.csv'

# Read shapefile
admin_gdf = aoi_admin

# Read CSV data
csv_data = pd.read_csv(csv_path)

print(csv_data.head())
print(admin_gdf.head())
# Convert column names to lowercase
csv_data['Kelurahan'] = csv_data['Kelurahan'].str.lower().str.replace(' ', '')
admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.lower().str.replace(' ', '')
#csv_data['Jumlah_KK'] = csv_data['Jumlah_KK'].astype(str).str.replace('.', '')
#csv_data['Jumlah_KK'] = pd.to_numeric(csv_data['Jumlah_KK'])

# Fix typo to merge properly
#admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.replace('pondokjagungt', 'pondokjagung')
#csv_data['Kelurahan'] = csv_data['Kelurahan'].str.replace('perigibaru', 'parigibaru')

# Merge data
merged_data = pd.merge(admin_gdf, csv_data, left_on='NAMOBJ', right_on='Kelurahan', how='left')

# Convert to GeoDataFrame
merged_gdf = gpd.GeoDataFrame(merged_data, geometry=merged_data.geometry)

print(merged_gdf.head())
# Now you can use merged_gdf for further analysis and visualization
# Out:
#     Kelurahan   2018   2017   2016
# 0   Argasunya  18717  18541  18374
# 1    Kalijaga  32115  31818  31533
# 2  Harjamukti  19818  19634  19458
# 3      Kecapi  23470  23254  23042
# 4    Larangan  14885  14744  14612
#        OBJECTID      NAMOBJ       FCODE REMARK  \
# 20250   20251.0   argasunya  BA03070040   None
# 20365   20366.0      drajat  BA03070040   None
# 20418   20419.0  harjamukti  BA03070040   None
# 20429   20430.0   jagasatru  BA03070040   None
# 20459   20460.0    kalijaga  BA03070040   None
#
#                                            METADATA     SRS_ID KDBBPS KDCBPS  \
# 20250  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 20365  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 20418  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 20429  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 20459  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#          KDCPUM KDEBPS  ...        WADMKK      WADMPR WIADKC WIADKK  WIADPR  \
# 20250  32.74.03   None  ...  Kota Cirebon  Jawa Barat   None   None    None
# 20365  32.74.05   None  ...  Kota Cirebon  Jawa Barat   None   None    None
# 20418  32.74.03   None  ...  Kota Cirebon  Jawa Barat   None   None    None
# 20429  32.74.04   None  ...  Kota Cirebon  Jawa Barat   None   None    None
# 20459  32.74.03   None  ...  Kota Cirebon  Jawa Barat   None   None    None
#
#        WIADKD                             UUPP Shape_Leng Shape_Area  \
# 20250    None  Hasil Delineasi Batas Desa 2019   0.131985   0.000559
# 20365    None  Hasil Delineasi Batas Desa 2019   0.046259   0.000076
# 20418    None  Hasil Delineasi Batas Desa 2019   0.081169   0.000192
# 20429    None  Hasil Delineasi Batas Desa 2019   0.029348   0.000029
# 20459    None  Hasil Delineasi Batas Desa 2019   0.132093   0.000346
#
#                                                 geometry
# 20250  POLYGON Z ((108.55591 -6.76549 0, 108.55579 -6...
# 20365  POLYGON Z ((108.56216 -6.72983 0, 108.56223 -6...
# 20418  POLYGON Z ((108.54801 -6.73947 0, 108.54805 -6...
# 20429  POLYGON Z ((108.56991 -6.72996 0, 108.56899 -6...
# 20459  POLYGON Z ((108.55911 -6.7544 0, 108.55935 -6....
#
# [5 rows x 28 columns]
#    OBJECTID      NAMOBJ       FCODE REMARK  \
# 0   20251.0   argasunya  BA03070040   None
# 1   20366.0      drajat  BA03070040   None
# 2   20419.0  harjamukti  BA03070040   None
# 3   20430.0   jagasatru  BA03070040   None
# 4   20460.0    kalijaga  BA03070040   None
#
#                                        METADATA     SRS_ID KDBBPS KDCBPS  \
# 0  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 1  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 2  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 3  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 4  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#      KDCPUM KDEBPS  ... WIADPR WIADKD                             UUPP  \
# 0  32.74.03   None  ...   None   None  Hasil Delineasi Batas Desa 2019
# 1  32.74.05   None  ...   None   None  Hasil Delineasi Batas Desa 2019
# 2  32.74.03   None  ...   None   None  Hasil Delineasi Batas Desa 2019
# 3  32.74.04   None  ...   None   None  Hasil Delineasi Batas Desa 2019
# 4  32.74.03   None  ...   None   None  Hasil Delineasi Batas Desa 2019
#
#   Shape_Leng  Shape_Area                                           geometry  \
# 0   0.131985    0.000559  POLYGON Z ((108.55591 -6.76549 0, 108.55579 -6...
# 1   0.046259    0.000076  POLYGON Z ((108.56216 -6.72983 0, 108.56223 -6...
# 2   0.081169    0.000192  POLYGON Z ((108.54801 -6.73947 0, 108.54805 -6...
# 3   0.029348    0.000029  POLYGON Z ((108.56991 -6.72996 0, 108.56899 -6...
# 4   0.132093    0.000346  POLYGON Z ((108.55911 -6.7544 0, 108.55935 -6....
#
#     Kelurahan   2018   2017   2016
# 0   argasunya  18717  18541  18374
# 1      drajat  15878  15729  15586
# 2  harjamukti  19818  19634  19458
# 3   jagasatru  10447  10349  10257
# 4    kalijaga  32115  31818  31533
#
# [5 rows x 32 columns]
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Create a base map
m = folium.Map(location=[-6.3, 106.7], zoom_start=11)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name='choropleth',
    data=merged_gdf,
    columns=["Kelurahan", "2017"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="2017"
).add_to(m)

jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='2017',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['WADMKD','2017'],
        aliases=['Kelurahan','2017']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc3d5818d677005e1aa0467b2f15736b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc3d5818d677005e1aa0467b2f15736b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc3d5818d677005e1aa0467b2f15736b = L.map(
#                 &quot;map_dc3d5818d677005e1aa0467b2f15736b&quot;,
#                 {
#                     center: [-6.3, 106.7],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77391dede692b24b34c8769cb574f54e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_77391dede692b24b34c8769cb574f54e.addTo(map_dc3d5818d677005e1aa0467b2f15736b);
#
#
#             var choropleth_fbd793eeeea8f035e8b88e9ec235d650 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_f5c22ac70b24c990ae72ed0a80c102f4_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;11&quot;: case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;10&quot;: case &quot;14&quot;: case &quot;18&quot;: case &quot;20&quot;: case &quot;21&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;5&quot;: case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_f5c22ac70b24c990ae72ed0a80c102f4_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f5c22ac70b24c990ae72ed0a80c102f4 = L.geoJson(null, {
#                 onEachFeature: geo_json_f5c22ac70b24c990ae72ed0a80c102f4_onEachFeature,
#
#                 style: geo_json_f5c22ac70b24c990ae72ed0a80c102f4_styler,
#         });
#
#         function geo_json_f5c22ac70b24c990ae72ed0a80c102f4_add (data) {
#             geo_json_f5c22ac70b24c990ae72ed0a80c102f4
#                 .addData(data);
#         }
#             geo_json_f5c22ac70b24c990ae72ed0a80c102f4_add({&quot;bbox&quot;: [108.51823084700004, -6.796386793999943, 108.59111272000007, -6.691326604999972], &quot;features&quot;: [{&quot;bbox&quot;: [108.52960491900006, -6.796386793999943, 108.55591073900007, -6.7536460099999545], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[108.55591073900007, -6.765487223999969, 0.0], [108.55579081400003, -6.765567694999959, 0.0], [108.55570723700004, -6.765620665999961, 0.0], [108.55562683100004, -6.765865480999935, 0.0], [108.55526217000005, -6.766862936999928, 0.0], [108.55502621300008, -6.767860391999932, 0.0], [108.55497638700007, -6.768140553999956, 0.0], [108.55490321500008, -6.768419968999979, 0.0], [108.55477886800008, -6.76888564799998, 0.0], [108.55465082600006, -6.769394114999955, 0.0], [108.55459719900006, -6.769694423999965, 0.0], [108.55455429800008, -6.76989284299998, 0.0], [108.55452212200004, -6.770171700999981, 0.0], [108.55446313300007, -6.7704880989999765, 0.0], [108.55435051700005, -6.7708742109999775, 0.0], [108.55429689000005, -6.771088716999941, 0.0], [108.55417891100006, -6.771523092999

# %%
# Create a base map
m = folium.Map(location=[-6.7426852,108.4716355], zoom_start=13)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name="Jumlah KK Kelurahan Cirebon",
    data=merged_gdf,
    columns=["Kelurahan", "2017"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="2017"
).add_to(m)

# Create/import data sma
data_sma = pd.read_csv('SMAN_CIREBON.csv')

data_sma['geometry'] = gpd.GeoSeries.from_wkt(data_sma['WKT'])

# Extract latitude and longitude from Point geometries
data_sma['latitude'] = data_sma['geometry'].apply(lambda x: x.y)
data_sma['longitude'] = data_sma['geometry'].apply(lambda x: x.x)

# Add markers to the map
# Create a marker layer
marker_layer = folium.FeatureGroup(name="SMAN CIREBON")

# Add markers to the layer
for i in range(0, len(data_sma)):
    folium.Marker([data_sma.iloc[i]['latitude'], data_sma.iloc[i]['longitude']], popup=data_sma.iloc[i]).add_to(marker_layer)

m.add_child(marker_layer)

# Add Jumlah_KK layer map
jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='Jumlah_KK',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['NAMOBJ','2017'],
        aliases=['Kelurahan','2017']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d074afb0e87c083cfd6bdea7452b726 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d074afb0e87c083cfd6bdea7452b726&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d074afb0e87c083cfd6bdea7452b726 = L.map(
#                 &quot;map_5d074afb0e87c083cfd6bdea7452b726&quot;,
#                 {
#                     center: [-6.7426852, 108.4716355],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_982166e95c8bc12e7b047b5da37a6dcb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_982166e95c8bc12e7b047b5da37a6dcb.addTo(map_5d074afb0e87c083cfd6bdea7452b726);
#
#
#             var choropleth_7c804799585db70822b35441c5afb974 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_ae02a255d867d678839ee18dc2e0133f_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;11&quot;: case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;10&quot;: case &quot;14&quot;: case &quot;18&quot;: case &quot;20&quot;: case &quot;21&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;5&quot;: case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ae02a255d867d678839ee18dc2e0133f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ae02a255d867d678839ee18dc2e0133f = L.geoJson(null, {
#                 onEachFeature: geo_json_ae02a255d867d678839ee18dc2e0133f_onEachFeature,
#
#                 style: geo_json_ae02a255d867d678839ee18dc2e0133f_styler,
#         });
#
#         function geo_json_ae02a255d867d678839ee18dc2e0133f_add (data) {
#             geo_json_ae02a255d867d678839ee18dc2e0133f
#                 .addData(data);
#         }
#             geo_json_ae02a255d867d678839ee18dc2e0133f_add({&quot;bbox&quot;: [108.51823084700004, -6.796386793999943, 108.59111272000007, -6.691326604999972], &quot;features&quot;: [{&quot;bbox&quot;: [108.52960491900006, -6.796386793999943, 108.55591073900007, -6.7536460099999545], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[108.55591073900007, -6.765487223999969, 0.0], [108.55579081400003, -6.765567694999959, 0.0], [108.55570723700004, -6.765620665999961, 0.0], [108.55562683100004, -6.765865480999935, 0.0], [108.55526217000005, -6.766862936999928, 0.0], [108.55502621300008, -6.767860391999932, 0.0], [108.55497638700007, -6.768140553999956, 0.0], [108.55490321500008, -6.768419968999979, 0.0], [108.55477886800008, -6.76888564799998, 0.0], [108.55465082600006, -6.769394114999955, 0.0], [108.55459719900006, -6.769694423999965, 0.0], [108.55455429800008, -6.76989284299998, 0.0], [108.55452212200004, -6.770171700999981, 0.0], [108.55446313300007, -6.7704880989999765, 0.0], [108.55435051700005, -6.7708742109999775, 0.0], [108.55429689000005, -6.771088716999941, 0.0], [108.55417891100006, -6.

# %% [markdown]
# Analysis Question:
# Kelurahan mana yang memiliki jumlah KK dengan kelas tertinggi (Merah Tua)?
#
# Jawab: kelurahan kalijaga
#
# Kelurahan apa saja yang tidak terdapat Sekolah Negeri?
#
# Jawab: Kelurahan Argasunya, Harjamukti, Kecapi, Pegambiran, Kesepuhan, Lemahwungkuk, Panjunan, Jagasatru, Pulasaren, Pekalipan, Pekalangan, Sunyaragi, Drajat, Kesambi, Pekiringan, Kejaksan, Kebon Baru, Sukapura, Kesenden.
