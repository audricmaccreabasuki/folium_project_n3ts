# %% [markdown]
# <a href="https://colab.research.google.com/github/khaficools/folium_project_n3ts/blob/main/safira_andriani_X_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Template Tugas Project
#
# 1. import folium, pandas, geopandas, dan drive.
# 2. load data shapefile, pilih kota/kabupaten yang akan dianalisis
# 3. load data csv dan proses merge/join data
# 4. load peta choropleth

# %%
# Import Library

import folium
import pandas as pd
import geopandas as gpd
from google.colab import drive

# %% [markdown]
# Pilih nama kota / kabupaten kalian. jika tidak muncul pastikan namanya sesuai dengan nama di link berikut :
# https://geoservices.big.go.id/portal/apps/webappviewer/index.html?id=cb58db080712468cb4bfd408dbde3d70
#
# ![e92f69dd74b6160e4611eee8c27905f0.png](data:image/png;base64,...)

# %%
# Read Data Shapefile

drive.mount('/content/drive')

# Shapefile Admin Indonesia (tidak usah diubah2) Warning! File besar 1.4gb
indonesia_admin = gpd.read_file('/content/drive/MyDrive/ADMIN_INDO/ADMINISTRASI_AR_DESAKEL_10K.shp')

# Pilih Kota/Kabupaten yang ingin ditampilkan, contoh 'Kota Tangerang Selatan'
aoi_admin = indonesia_admin[indonesia_admin['WADMKK'] == 'Kota Yogyakarta']
# Out:
# Mounted at /content/drive

# %%
# CSV file path
csv_path = '/content/Yogyakarta_KK.csv'

# Read shapefile
admin_gdf = aoi_admin

# Read CSV data
csv_data = pd.read_csv(csv_path)

print(csv_data.head())
print(admin_gdf.head())
# Convert column names to lowercase
csv_data['KELURAHAN'] = csv_data['KELURAHAN'].str.lower().str.replace(' ', '')
admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.lower().str.replace(' ', '')
#csv_data['Jumlah_KK'] = csv_data['Jumlah_KK'].astype(str).str.replace('.', '')
#csv_data['Jumlah_KK'] = pd.to_numeric(csv_data['Jumlah_KK'])

# Fix typo to merge properly
#admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.replace('pondokjagungt', 'pondokjagung')
#csv_data['Kelurahan'] = csv_data['Kelurahan'].str.replace('perigibaru', 'parigibaru')

# Merge data
merged_data = pd.merge(admin_gdf, csv_data, left_on='NAMOBJ', right_on='KELURAHAN', how='left')

# Convert to GeoDataFrame
merged_gdf = gpd.GeoDataFrame(merged_data, geometry=merged_data.geometry)

print(merged_gdf.head())
# Now you can use merged_gdf for further analysis and visualization
# Out:
#      KECAMATAN          KELURAHAN  TOTAL
# 0  Mantrijeron         Gedongkiwo  13923
# 1  Mantrijeron   Suryodiningratan  11291
# 2  Mantrijeron        Mantrijeron   9974
# 3       Kraton            Patehan   5872
# 4       Kraton         Panembahan   8995
#       OBJECTID         NAMOBJ       FCODE REMARK  \
# 1843    1844.0         Baciro  BA03070040   None
# 1857    1858.0      Bausasran  BA03070040   None
# 1860    1861.0          Bener  BA03070040   None
# 1862    1863.0  Brontokusuman  BA03070040   None
# 1865    1866.0         Bumijo  BA03070040   None
#
#                                           METADATA     SRS_ID KDBBPS KDCBPS  \
# 1843  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 1857  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 1860  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 1862  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 1865  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#         KDCPUM KDEBPS  ...           WADMKK                      WADMPR  \
# 1843  34.71.03   None  ...  Kota Yogyakarta  Daerah Istimewa Yogyakarta
# 1857  34.71.04   None  ...  Kota Yogyakarta  Daerah Istimewa Yogyakarta
# 1860  34.71.01   None  ...  Kota Yogyakarta  Daerah Istimewa Yogyakarta
# 1862  34.71.12   None  ...  Kota Yogyakarta  Daerah Istimewa Yogyakarta
# 1865  34.71.02   None  ...  Kota Yogyakarta  Daerah Istimewa Yogyakarta
#
#      WIADKC WIADKK  WIADPR  WIADKD                     UUPP Shape_Leng  \
# 1843   None   None    None    None  Data RBI Skala 1:25.000   0.054191
# 1857   None   None    None    None  Data RBI Skala 1:25.000   0.028896
# 1860   None   None    None    None  Data RBI Skala 1:25.000   0.045199
# 1862   None   None    None    None  Data RBI Skala 1:25.000   0.041636
# 1865   None   None    None    None  Data RBI Skala 1:25.000   0.030781
#
#      Shape_Area                                           geometry
# 1843   0.000089  POLYGON Z ((110.396 -7.78858 0, 110.396 -7.788...
# 1857   0.000039  POLYGON Z ((110.37818 -7.7898 0, 110.37813 -7....
# 1860   0.000052  POLYGON Z ((110.35227 -7.77199 0, 110.35233 -7...
# 1862   0.000078  POLYGON Z ((110.37464 -7.81549 0, 110.37487 -7...
# 1865   0.000052  POLYGON Z ((110.36092 -7.78008 0, 110.36088 -7...
#
# [5 rows x 28 columns]
#    OBJECTID         NAMOBJ       FCODE REMARK  \
# 0    1844.0         baciro  BA03070040   None
# 1    1858.0      bausasran  BA03070040   None
# 2    1861.0          bener  BA03070040   None
# 3    1863.0  brontokusuman  BA03070040   None
# 4    1866.0         bumijo  BA03070040   None
#
#                                        METADATA     SRS_ID KDBBPS KDCBPS  \
# 0  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 1  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 2  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 3  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 4  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#      KDCPUM KDEBPS  ... WIADKK WIADPR WIADKD                     UUPP  \
# 0  34.71.03   None  ...   None   None   None  Data RBI Skala 1:25.000
# 1  34.71.04   None  ...   None   None   None  Data RBI Skala 1:25.000
# 2  34.71.01   None  ...   None   None   None  Data RBI Skala 1:25.000
# 3  34.71.12   None  ...   None   None   None  Data RBI Skala 1:25.000
# 4  34.71.02   None  ...   None   None   None  Data RBI Skala 1:25.000
#
#    Shape_Leng  Shape_Area                                           geometry  \
# 0    0.054191    0.000089  POLYGON Z ((110.396 -7.78858 0, 110.396 -7.788...
# 1    0.028896    0.000039  POLYGON Z ((110.37818 -7.7898 0, 110.37813 -7....
# 2    0.045199    0.000052  POLYGON Z ((110.35227 -7.77199 0, 110.35233 -7...
# 3    0.041636    0.000078  POLYGON Z ((110.37464 -7.81549 0, 110.37487 -7...
# 4    0.030781    0.000052  POLYGON Z ((110.36092 -7.78008 0, 110.36088 -7...
#
#       KECAMATAN      KELURAHAN    TOTAL
# 0  Gondokusuman         baciro  12196.0
# 1    Pakualaman      bausasran   7425.0
# 2     Tegalrejo          bener   4967.0
# 3    Mergangsan  brontokusuman  10816.0
# 4         Jetis         bumijo  10245.0
#
# [5 rows x 31 columns]
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Create a base map
m = folium.Map(location=[-7.8014646921441155, 110.3642019448877], zoom_start=11)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name='choropleth',
    data=merged_gdf,
    columns=["KELURAHAN", "TOTAL"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="Jumlah Penduduk"
).add_to(m)

jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='Jumlah_KK',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['WADMKD','TOTAL'],
        aliases=['Kelurahan','Jumlah Penduduk']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d668b0d9d1eb26df5f9e1e2f1a6b9727 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d668b0d9d1eb26df5f9e1e2f1a6b9727&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d668b0d9d1eb26df5f9e1e2f1a6b9727 = L.map(
#                 &quot;map_d668b0d9d1eb26df5f9e1e2f1a6b9727&quot;,
#                 {
#                     center: [-7.8014646921441155, 110.3642019448877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1d0728906ab6e47a747dd1c25b73f28f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1d0728906ab6e47a747dd1c25b73f28f.addTo(map_d668b0d9d1eb26df5f9e1e2f1a6b9727);
#
#
#             var choropleth_2090e274ba7a6cf84fdc094b27398f8f = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_435084dda5e4a1b2a2ec01a2aceba09f_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;16&quot;: case &quot;23&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;32&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;13&quot;: case &quot;21&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;27&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;40&quot;: case &quot;41&quot;: case &quot;42&quot;: case &quot;43&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;10&quot;: case &quot;15&quot;: case &quot;33&quot;: case &quot;36&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;4&quot;: case &quot;12&quot;: case &quot;14&quot;: case &quot;17&quot;: case &quot;19&quot;: case &quot;22&quot;: case &quot;30&quot;: case &quot;37&quot;: case &quot;44&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;11&quot;: case &quot;20&quot;: case &quot;26&quot;: case &quot;31&quot;: case &quot;35&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;18&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_435084dda5e4a1b2a2ec01a2aceba09f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_435084dda5e4a1b2a2ec01a2aceba09f = L.geoJson(null, {
#                 onEachFeature: geo_json_435084dda5e4a1b2a2ec01a2aceba09f_onEachFeature,
#
#                 style: geo_json_435084dda5e4a1b2a2ec01a2aceba09f_styler,
#         });
#
#         function geo_json_435084dda5e4a1b2a2ec01a2aceba09f_add (data) {
#             geo_json_435084dda5e4a1b2a2ec01a2aceba09f
#                 .addData(data);
#         }
#             geo_json_435084dda5e4a1b2a2ec01a2aceba09f_add({&quot;bbox&quot;: [110.34479964200005, -7.8400724519999585, 110.40510745500006, -7.766468011999962], &quot;features&quot;: [{&quot;bbox&quot;: [110.37762800000007, -7.798198999999954, 110.39600300000006, -7.788471619999939], &quot;geometry&quot;:

# %%
# Create a base map
m = folium.Map(location=[-7.80044425566166, 110.3657468972421], zoom_start=13)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name="Jumlah KK Kelurahan Tangsel",
    data=merged_gdf,
    columns=["KELURAHAN", "TOTAL"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="Jumlah Penduduk"
).add_to(m)

# Create/import data sma
data_sma = pd.read_csv('point_sman_yogyakarta (1).csv')

data_sma['geometry'] = gpd.GeoSeries.from_wkt(data_sma['WKT'])

# Extract latitude and longitude from Point geometries
data_sma['latitude'] = data_sma['geometry'].apply(lambda x: x.y)
data_sma['longitude'] = data_sma['geometry'].apply(lambda x: x.x)

# Add markers to the map
# Create a marker layer
marker_layer = folium.FeatureGroup(name="SMAN Yogyakarta")

# Add markers to the layer
for i in range(0, len(data_sma)):
    folium.Marker([data_sma.iloc[i]['latitude'], data_sma.iloc[i]['longitude']], popup=data_sma.iloc[i]['nama']).add_to(marker_layer)

m.add_child(marker_layer)

# Add Jumlah_KK layer map
jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='Jumlah_KK',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['NAMOBJ','TOTAL'],
        aliases=['Kelurahan','Jumlah Penduduk']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7c7810dd3caea7275e02c992a66d2c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7c7810dd3caea7275e02c992a66d2c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7c7810dd3caea7275e02c992a66d2c6 = L.map(
#                 &quot;map_b7c7810dd3caea7275e02c992a66d2c6&quot;,
#                 {
#                     center: [-7.80044425566166, 110.3657468972421],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dda612f53139b1e4971f1b3f71a70a51 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dda612f53139b1e4971f1b3f71a70a51.addTo(map_b7c7810dd3caea7275e02c992a66d2c6);
#
#
#             var choropleth_be61e9ec386c78cc054a6a8843e46f9e = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_57ad4f447f0c79fd163ec444f962f479_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;16&quot;: case &quot;23&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;32&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;13&quot;: case &quot;21&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;27&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;40&quot;: case &quot;41&quot;: case &quot;42&quot;: case &quot;43&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;10&quot;: case &quot;15&quot;: case &quot;33&quot;: case &quot;36&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;4&quot;: case &quot;12&quot;: case &quot;14&quot;: case &quot;17&quot;: case &quot;19&quot;: case &quot;22&quot;: case &quot;30&quot;: case &quot;37&quot;: case &quot;44&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;11&quot;: case &quot;20&quot;: case &quot;26&quot;: case &quot;31&quot;: case &quot;35&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;18&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_57ad4f447f0c79fd163ec444f962f479_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_57ad4f447f0c79fd163ec444f962f479 = L.geoJson(null, {
#                 onEachFeature: geo_json_57ad4f447f0c79fd163ec444f962f479_onEachFeature,
#
#                 style: geo_json_57ad4f447f0c79fd163ec444f962f479_styler,
#         });
#
#         function geo_json_57ad4f447f0c79fd163ec444f962f479_add (data) {
#             geo_json_57ad4f447f0c79fd163ec444f962f479
#                 .addData(data);
#         }
#             geo_json_57ad4f447f0c79fd163ec444f962f479_add({&quot;bbox&quot;: [110.34479964200005, -7.8400724519999585, 110.40510745500006, -7.766468011999962], &quot;features&quot;: [{&quot;bbox&quot;: [110.37762800000007, -7.798198999999954, 110.39600300000006, -7.788471619999939], &quot;geometry&quot;: {&

# %% [markdown]
# Analysis Question:
# Kelurahan mana yang memiliki jumlah KK dengan kelas tertinggi (Merah Tua)?
#
# Jawab:
#
# Kelurahan apa saja yang tidak terdapat Sekolah Negeri?
#
# Jawab:

# %% [markdown]
# 1.   gedongkiwo
# 2.   sorosutan

# %% [markdown]
# 2.
# Gedongkiwo
#
# Mantrijeron
#
# Patehan
#
# Panembahan
#
# Kadipaten
#
# Brontokusuman
#
# Keparakan
#
# Wirogunan
#
# Giwangan
#
# Sorosutan
#
# Pandeyan
#
# Warungboto
#
# Tahunan
#
# Semaki
#
# Purbayan
#
# Rejowinangun
#
# Baciro
#
# Demangan
#
# Klitren
#
# Kotabaru
#
# Suryatmajan
#
# Tegalpanggung
#
# Bausasran
#
# Purwokinanti
#
# Gunungketur
#
# Prawirodirjan
#
# Notoprajan
#
# Ngampilan
#
# Patangpuluhan
#
# Wirobrajan
#
# Pringgokusuman
#
# Sosromenduran
#
# Bumijo
#
# Gowongan
#
# Tegalrejo
#
# Kricak
