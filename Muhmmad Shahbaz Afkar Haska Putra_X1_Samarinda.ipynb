# %% [markdown]
# <a href="https://colab.research.google.com/github/afkarhsk/folium_project_n3ts/blob/main/Muhmmad%20Shahbaz%20Afkar%20Haska%20Putra_X1_Samarinda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Template Tugas Project
#
# 1. import folium, pandas, geopandas, dan drive.
# 2. load data shapefile, pilih kota/kabupaten yang akan dianalisis
# 3. load data csv dan proses merge/join data
# 4. load peta choropleth

# %%
# Import Library

import folium
import pandas as pd
import geopandas as gpd
from google.colab import drive

# %% [markdown]
# Pilih nama kota / kabupaten kalian. jika tidak muncul pastikan namanya sesuai dengan nama di link berikut :
# https://geoservices.big.go.id/portal/apps/webappviewer/index.html?id=cb58db080712468cb4bfd408dbde3d70
#
# ![e92f69dd74b6160e4611eee8c27905f0.png](data:image/png;base64,...)

# %%
# Read Data Shapefile

drive.mount('/content/drive')

# Shapefile Admin Indonesia (tidak usah diubah2) Warning! File besar 1.4gb
indonesia_admin = gpd.read_file('/content/drive/MyDrive/ADMIN_INDO/ADMINISTRASI_AR_DESAKEL_10K.shp')

# Pilih Kota/Kabupaten yang ingin ditampilkan, contoh 'Kota Tangerang Selatan'
aoi_admin = indonesia_admin[indonesia_admin['WADMKK'] == 'Kota Samarinda']
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# CSV file path
csv_path = '/content/drive/MyDrive/KK_Samarinda.csv'

# Read shapefile
admin_gdf = aoi_admin

# Read CSV data
csv_data = pd.read_csv(csv_path)

print(csv_data.head())
print(admin_gdf.head())
# Convert column names to lowercase
csv_data['Kelurahan'] = csv_data['Kelurahan'].str.lower().str.replace(' ', '')
admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.lower().str.replace(' ', '')
#csv_data['Jumlah_KK'] = csv_data['Jumlah_KK'].astype(str).str.replace('.', '')
#csv_data['Jumlah_KK'] = pd.to_numeric(csv_data['Jumlah_KK'])

# Fix typo to merge properly
#admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.replace('pondokjagungt', 'pondokjagung')
#csv_data['Kelurahan'] = csv_data['Kelurahan'].str.replace('perigibaru', 'parigibaru')

# Merge data
merged_data = pd.merge(admin_gdf, csv_data, left_on='NAMOBJ', right_on='Kelurahan', how='left')

# Convert to GeoDataFrame
merged_gdf = gpd.GeoDataFrame(merged_data, geometry=merged_data.geometry)

print(merged_gdf.head())
# Now you can use merged_gdf for further analysis and visualization
# Out:
#        Kelurahan  Jumlah KK
# 0  Simpang Pasir       9362
# 1   Handil Bakti      10678
# 2        Bantuas       4744
# 3         Bukuan      16972
# 4    Rawa Makmur      23443
#        OBJECTID     NAMOBJ       FCODE REMARK  \
# 47313   47314.0  Air Hitam  BA03070040   None
# 47315   47316.0  Air Putih  BA03070040   None
# 47448   47449.0    Bandara  BA03070040   None
# 47477   47478.0    Bantuas  BA03070040   None
# 47493   47494.0       Baqa  BA03070040   None
#
#                                            METADATA     SRS_ID KDBBPS KDCBPS  \
# 47313  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 47315  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 47448  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 47477  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 47493  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#          KDCPUM KDEBPS  ...          WADMKK            WADMPR WIADKC WIADKK  \
# 47313  64.72.03   None  ...  Kota Samarinda  Kalimantan Timur   None   None
# 47315  64.72.03   None  ...  Kota Samarinda  Kalimantan Timur   None   None
# 47448  64.72.08   None  ...  Kota Samarinda  Kalimantan Timur   None   None
# 47477  64.72.01   None  ...  Kota Samarinda  Kalimantan Timur   None   None
# 47493  64.72.02   None  ...  Kota Samarinda  Kalimantan Timur   None   None
#
#        WIADPR  WIADKD                                    UUPP Shape_Leng  \
# 47313    None    None  Data dari Pemerintah Daerah Tahun 2021   0.216953
# 47315    None    None  Data dari Pemerintah Daerah Tahun 2021   0.133328
# 47448    None    None  Data dari Pemerintah Daerah Tahun 2021   0.036993
# 47477    None    None  Data dari Pemerintah Daerah Tahun 2021   0.516741
# 47493    None    None  Data dari Pemerintah Daerah Tahun 2021   0.054223
#
#       Shape_Area                                           geometry
# 47313   0.001580  POLYGON Z ((117.13893 -0.44829 0, 117.13824 -0...
# 47315   0.000486  POLYGON Z ((117.13344 -0.4818 0, 117.13351 -0....
# 47448   0.000055  POLYGON Z ((117.15917 -0.48199 0, 117.15778 -0...
# 47477   0.005333  POLYGON Z ((117.27508 -0.58352 0, 117.27471 -0...
# 47493   0.000141  POLYGON Z ((117.13467 -0.5029 0, 117.13537 -0....
#
# [5 rows x 28 columns]
#    OBJECTID    NAMOBJ       FCODE REMARK  \
# 0   47314.0  airhitam  BA03070040   None
# 1   47316.0  airputih  BA03070040   None
# 2   47449.0   bandara  BA03070040   None
# 3   47478.0   bantuas  BA03070040   None
# 4   47494.0      baqa  BA03070040   None
#
#                                        METADATA     SRS_ID KDBBPS KDCBPS  \
# 0  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 1  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 2  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 3  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 4  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#      KDCPUM KDEBPS  ... WIADKC WIADKK WIADPR WIADKD  \
# 0  64.72.03   None  ...   None   None   None   None
# 1  64.72.03   None  ...   None   None   None   None
# 2  64.72.08   None  ...   None   None   None   None
# 3  64.72.01   None  ...   None   None   None   None
# 4  64.72.02   None  ...   None   None   None   None
#
#                                      UUPP  Shape_Leng Shape_Area  \
# 0  Data dari Pemerintah Daerah Tahun 2021    0.216953   0.001580
# 1  Data dari Pemerintah Daerah Tahun 2021    0.133328   0.000486
# 2  Data dari Pemerintah Daerah Tahun 2021    0.036993   0.000055
# 3  Data dari Pemerintah Daerah Tahun 2021    0.516741   0.005333
# 4  Data dari Pemerintah Daerah Tahun 2021    0.054223   0.000141
#
#                                             geometry Kelurahan Jumlah KK
# 0  POLYGON Z ((117.13893 -0.44829 0, 117.13824 -0...  airhitam     16315
# 1  POLYGON Z ((117.13344 -0.4818 0, 117.13351 -0....  airputih     29984
# 2  POLYGON Z ((117.15917 -0.48199 0, 117.15778 -0...   bandara      8156
# 3  POLYGON Z ((117.27508 -0.58352 0, 117.27471 -0...   bantuas      4744
# 4  POLYGON Z ((117.13467 -0.5029 0, 117.13537 -0....      baqa     14741
#
# [5 rows x 30 columns]
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Create a base map
m = folium.Map(location=[-0.76068056, 116.82944444], zoom_start=10)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name='choropleth',
    data=merged_gdf,
    columns=["Kelurahan", "Jumlah KK"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="Jumlah KK"
).add_to(m)

jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='Jumlah_KK',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['WADMKD','Jumlah KK'],
        aliases=['Kelurahan','Jumlah KK']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08277bc3a23aa9af80d7259d4971489a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08277bc3a23aa9af80d7259d4971489a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08277bc3a23aa9af80d7259d4971489a = L.map(
#                 &quot;map_08277bc3a23aa9af80d7259d4971489a&quot;,
#                 {
#                     center: [-0.76068056, 116.82944444],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a08cf577b58efa1f498f430116f256b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0a08cf577b58efa1f498f430116f256b.addTo(map_08277bc3a23aa9af80d7259d4971489a);
#
#
#             var choropleth_41b3efb11144a0824fb89911f98010ce = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_15d133c2ac1e4751cff3c09adf682148_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;4&quot;: case &quot;7&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;13&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;30&quot;: case &quot;35&quot;: case &quot;37&quot;: case &quot;43&quot;: case &quot;44&quot;: case &quot;45&quot;: case &quot;47&quot;: case &quot;48&quot;: case &quot;51&quot;: case &quot;53&quot;: case &quot;55&quot;: case &quot;56&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;21&quot;: case &quot;34&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;3&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;12&quot;: case &quot;19&quot;: case &quot;22&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;31&quot;: case &quot;36&quot;: case &quot;40&quot;: case &quot;46&quot;: case &quot;52&quot;: case &quot;54&quot;: case &quot;58&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;23&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;50&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_15d133c2ac1e4751cff3c09adf682148_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_15d133c2ac1e4751cff3c09adf682148 = L.geoJson(null, {
#                 onEachFeature: geo_json_15d133c2ac1e4751cff3c09adf682148_onEachFeature,
#
#                 style: geo_json_15d133c2ac1e4751cff3c09adf682148_styler,
#         });
#
#         function geo_json_15d133c2ac1e4751cff3c09adf682148_add (data) {
#             geo_json_15d133c2ac1e4751cff3c09adf682148
#                 .addData(data);
#         }
#             geo_json_15d133c2ac1e4751cff3c09adf682148_add({&quot;bbox&quot;: [117.0539500000001, -0.7167639759999247, 117.29823001300008, -0.3143609999999626], &quot;features&quot;: [{&quot;bbox&quot;: [117.09340433900002, -0.4820759919999773, 117.1402796110001, -0.40882426399997485], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[117.13892931400005, -0.44828546299993377, 0.0], [117.13823822000006, -0.44837441399994304, 0.0], [117

# %% [markdown]
# Analysis Question:
# Kelurahan mana yang memiliki jumlah KK dengan kelas tertinggi (Merah Tua)?
#
# Jawab: Sungai Pinang Dalam
