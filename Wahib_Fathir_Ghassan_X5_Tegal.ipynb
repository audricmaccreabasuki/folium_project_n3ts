# %% [markdown]
# <a href="https://colab.research.google.com/github/WahibFathirGhassan/folium_project_n3ts/blob/main/Wahib_Fathir_Ghassan_X5_Tegal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Template Tugas Project
#
# 1. import folium, pandas, geopandas, dan drive.
# 2. load data shapefile, pilih kota/kabupaten yang akan dianalisis
# 3. load data csv dan proses merge/join data
# 4. load peta choropleth

# %%
# Import Library

import folium
import pandas as pd
import geopandas as gpd
from google.colab import drive

# %% [markdown]
# Pilih nama kota / kabupaten kalian. jika tidak muncul pastikan namanya sesuai dengan nama di link berikut :
# https://geoservices.big.go.id/portal/apps/webappviewer/index.html?id=cb58db080712468cb4bfd408dbde3d70
#
# ![e92f69dd74b6160e4611eee8c27905f0.png](data:image/png;base64,...)

# %%
# Read Data Shapefile

drive.mount('/content/drive')

# Shapefile Admin Indonesia (tidak usah diubah2) Warning! File besar 1.4gb
indonesia_admin = gpd.read_file('/content/drive/MyDrive/ADMIN_INDO/ADMINISTRASI_AR_DESAKEL_10K.shp')

# Pilih Kota/Kabupaten yang ingin ditampilkan, contoh 'Kota Tangerang Selatan'
aoi_admin = indonesia_admin[indonesia_admin['WADMKK'] == 'Kota Tegal']
# Out:
# Mounted at /content/drive

# %%
# CSV file path
csv_path = '/content/kelurahan_tegal.csv'

# Read shapefile
admin_gdf = aoi_admin

# Read CSV data
csv_data = pd.read_csv(csv_path, header = 0, delimiter= ';')

print(csv_data.head())
print(admin_gdf.head())
# Convert column names to lowercase
csv_data['Kelurahan'] = csv_data['Kelurahan'].str.lower().str.replace(' ', '')
admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.lower().str.replace(' ', '')
#csv_data['Jumlah_KK'] = csv_data['Jumlah_KK'].astype(str).str.replace('.', '')
#csv_data['Jumlah_KK'] = pd.to_numeric(csv_data['Jumlah_KK'])

# Fix typo to merge properly
#admin_gdf['NAMOBJ'] = admin_gdf['NAMOBJ'].str.replace('pondokjagungt', 'pondokjagung')
#csv_data['Kelurahan'] = csv_data['Kelurahan'].str.replace('perigibaru', 'parigibaru')

# Merge data
merged_data = pd.merge(admin_gdf, csv_data, left_on='NAMOBJ', right_on='Kelurahan', how='left')

# Convert to GeoDataFrame
merged_gdf = gpd.GeoDataFrame(merged_data, geometry=merged_data.geometry)

print(merged_gdf.head())
# Now you can use merged_gdf for further analysis and visualization
# Out:
#           Kelurahan  Jumlah
# 0  Pesurungan Kidul    6337
# 1        Debong Lor    4604
# 2       Kemandungan    3798
# 3          Pekauman    7812
# 4            Kraton   15897
#        OBJECTID        NAMOBJ       FCODE REMARK  \
# 21018   21019.0       Bandung  BA03070040   None
# 21057   21058.0       Cabawan  BA03070040   None
# 21066   21067.0  Debong Kidul  BA03070040   None
# 21067   21068.0  Debong Kulon  BA03070040   None
# 21068   21069.0    Debong Lor  BA03070040   None
#
#                                            METADATA     SRS_ID KDBBPS KDCBPS  \
# 21018  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 21057  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 21066  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 21067  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 21068  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#          KDCPUM KDEBPS  ...      WADMKK       WADMPR WIADKC WIADKK  WIADPR  \
# 21018  33.76.03   None  ...  Kota Tegal  Jawa Tengah   None   None    None
# 21057  33.76.04   None  ...  Kota Tegal  Jawa Tengah   None   None    None
# 21066  33.76.03   None  ...  Kota Tegal  Jawa Tengah   None   None    None
# 21067  33.76.03   None  ...  Kota Tegal  Jawa Tengah   None   None    None
# 21068  33.76.01   None  ...  Kota Tegal  Jawa Tengah   None   None    None
#
#        WIADKD                             UUPP Shape_Leng Shape_Area  \
# 21018    None  Hasil Delineasi Batas Desa 2019   0.038900   0.000057
# 21057    None  Hasil Delineasi Batas Desa 2019   0.058776   0.000103
# 21066    None  Hasil Delineasi Batas Desa 2019   0.027539   0.000038
# 21067    None  Hasil Delineasi Batas Desa 2019   0.048564   0.000074
# 21068    None  Hasil Delineasi Batas Desa 2019   0.048511   0.000044
#
#                                                 geometry
# 21018  POLYGON Z ((109.12272 -6.89217 0, 109.12272 -6...
# 21057  POLYGON Z ((109.09492 -6.86381 0, 109.09498 -6...
# 21066  POLYGON Z ((109.12593 -6.89644 0, 109.12583 -6...
# 21067  POLYGON Z ((109.12503 -6.88388 0, 109.12501 -6...
# 21068  POLYGON Z ((109.12723 -6.87663 0, 109.12723 -6...
#
# [5 rows x 28 columns]
#    OBJECTID       NAMOBJ       FCODE REMARK  \
# 0   21019.0      bandung  BA03070040   None
# 1   21058.0      cabawan  BA03070040   None
# 2   21067.0  debongkidul  BA03070040   None
# 3   21068.0  debongkulon  BA03070040   None
# 4   21069.0    debonglor  BA03070040   None
#
#                                        METADATA     SRS_ID KDBBPS KDCBPS  \
# 0  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 1  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 2  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 3  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 4  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
#
#      KDCPUM KDEBPS  ... WIADKC WIADKK WIADPR WIADKD  \
# 0  33.76.03   None  ...   None   None   None   None
# 1  33.76.04   None  ...   None   None   None   None
# 2  33.76.03   None  ...   None   None   None   None
# 3  33.76.03   None  ...   None   None   None   None
# 4  33.76.01   None  ...   None   None   None   None
#
#                               UUPP  Shape_Leng Shape_Area  \
# 0  Hasil Delineasi Batas Desa 2019    0.038900   0.000057
# 1  Hasil Delineasi Batas Desa 2019    0.058776   0.000103
# 2  Hasil Delineasi Batas Desa 2019    0.027539   0.000038
# 3  Hasil Delineasi Batas Desa 2019    0.048564   0.000074
# 4  Hasil Delineasi Batas Desa 2019    0.048511   0.000044
#
#                                             geometry    Kelurahan Jumlah
# 0  POLYGON Z ((109.12272 -6.89217 0, 109.12272 -6...      bandung   6891
# 1  POLYGON Z ((109.09492 -6.86381 0, 109.09498 -6...      cabawan   6518
# 2  POLYGON Z ((109.12593 -6.89644 0, 109.12583 -6...  debongkidul   6206
# 3  POLYGON Z ((109.12503 -6.88388 0, 109.12501 -6...  debongkulon   5715
# 4  POLYGON Z ((109.12723 -6.87663 0, 109.12723 -6...    debonglor   4604
#
# [5 rows x 30 columns]
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Create a base map
m = folium.Map(location=[-6.475655762494614, 106.7157400696212], zoom_start=11)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name='choropleth',
    data=merged_gdf,
    columns=["Kelurahan", "Jumlah"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="Jumlah KK"
).add_to(m)

jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='Jumlah_KK',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['WADMKD','Jumlah'],
        aliases=['Kelurahan','Jumlah KK']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f02b7fb4032e466209a5d574d6cdc526 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f02b7fb4032e466209a5d574d6cdc526&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f02b7fb4032e466209a5d574d6cdc526 = L.map(
#                 &quot;map_f02b7fb4032e466209a5d574d6cdc526&quot;,
#                 {
#                     center: [-6.475655762494614, 106.7157400696212],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c29eb6962a2cb65c614628f0b812c0e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0c29eb6962a2cb65c614628f0b812c0e.addTo(map_f02b7fb4032e466209a5d574d6cdc526);
#
#
#             var choropleth_6c7c1db7653906f1f070c084072bff9a = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_1f77335d6e3108e5695f935b2f133d3a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;14&quot;: case &quot;17&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;24&quot;: case &quot;26&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;5&quot;: case &quot;9&quot;: case &quot;13&quot;: case &quot;15&quot;: case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;18&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;22&quot;: case &quot;23&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;25&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_1f77335d6e3108e5695f935b2f133d3a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1f77335d6e3108e5695f935b2f133d3a = L.geoJson(null, {
#                 onEachFeature: geo_json_1f77335d6e3108e5695f935b2f133d3a_onEachFeature,
#
#                 style: geo_json_1f77335d6e3108e5695f935b2f133d3a_styler,
#         });
#
#         function geo_json_1f77335d6e3108e5695f935b2f133d3a_add (data) {
#             geo_json_1f77335d6e3108e5695f935b2f133d3a
#                 .addData(data);
#         }
#             geo_json_1f77335d6e3108e5695f935b2f133d3a_add({&quot;bbox&quot;: [109.07493018100007, -6.899166055999956, 109.16167113100005, -6.839585382999928], &quot;features&quot;: [{&quot;bbox&quot;: [109.11269438500005, -6.899166055999956, 109.12271571300005, -6.890301474999944], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[109.12271571300005, -6.892172286999937, 0.0], [109.12271516300007, -6.892174399999931, 0.0], [109.12255509900007, -6.892789756999946, 0.0], [109.12242303900007, -6.8933001509999485, 0.0], [109.12230882500006, -6.89369990199998, 0.0], [109.12215535000007, -6.8940603889999466, 0.0], [109.12207682700006, -6.894385185999965, 0.0], [109.12204827400006, -6.894638598999961, 0.0], [109.12205541200007, -6.894824195999945, 0.0], [109.12206968900006, -6.89492413399995, 0.0], [109.12214464200008, -6.895138284999973, 0.0], [109.122162488000

# %%
# Create a base map
m = folium.Map(location=[-6.475655762494614, 106.7157400696212], zoom_start=13)

# Create a choropleth map
choropleth = folium.Choropleth(
    geo_data=merged_gdf,
    name="Jumlah KK Kelurahan Tangsel",
    data=merged_gdf,
    columns=["Kelurahan", "Jumlah"],
    key_on= "feature.properties.NAMOBJ",
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=1,
    legend_name="Jumlah KK"
).add_to(m)

# Create/import data sma
data_sma = pd.read_csv('sman_tegal.csv')

data_sma['geometry'] = gpd.GeoSeries.from_wkt(data_sma['WKT'])

# Extract latitude and longitude from Point geometries
data_sma['latitude'] = data_sma['geometry'].apply(lambda x: x.y)
data_sma['longitude'] = data_sma['geometry'].apply(lambda x: x.x)

# Add markers to the map
# Create a marker layer
marker_layer = folium.FeatureGroup(name="SMAN Tangerang Selatan")

# Add markers to the layer
for i in range(0, len(data_sma)):
    folium.Marker([data_sma.iloc[i]['latitude'], data_sma.iloc[i]['longitude']], popup=data_sma.iloc[i]['nama']).add_to(marker_layer)

m.add_child(marker_layer)

# Add Jumlah_KK layer map
jumlah_KK = folium.GeoJson(
    data=merged_gdf,
    name='Jumlah_KK',
    style_function=lambda feature: {'fillOpacity': 0, 'color': 'transparent'},
    popup = folium.GeoJsonPopup(
        fields=['NAMOBJ','Jumlah'],
        aliases=['Kelurahan','Jumlah KK']
    )
).add_to(choropleth)

folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2dd9f304a7cb9ee4729de273ba1dfe43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2dd9f304a7cb9ee4729de273ba1dfe43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2dd9f304a7cb9ee4729de273ba1dfe43 = L.map(
#                 &quot;map_2dd9f304a7cb9ee4729de273ba1dfe43&quot;,
#                 {
#                     center: [-6.475655762494614, 106.7157400696212],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_664080e61ee6f8f9702f9852f6064eea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_664080e61ee6f8f9702f9852f6064eea.addTo(map_2dd9f304a7cb9ee4729de273ba1dfe43);
#
#
#             var choropleth_52d574c42257b4fb7f097728a0486255 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_bf3b5c514b78b496f3b1df53fc37122a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;14&quot;: case &quot;17&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;24&quot;: case &quot;26&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;5&quot;: case &quot;9&quot;: case &quot;13&quot;: case &quot;15&quot;: case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;18&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;22&quot;: case &quot;23&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;25&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_bf3b5c514b78b496f3b1df53fc37122a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_bf3b5c514b78b496f3b1df53fc37122a = L.geoJson(null, {
#                 onEachFeature: geo_json_bf3b5c514b78b496f3b1df53fc37122a_onEachFeature,
#
#                 style: geo_json_bf3b5c514b78b496f3b1df53fc37122a_styler,
#         });
#
#         function geo_json_bf3b5c514b78b496f3b1df53fc37122a_add (data) {
#             geo_json_bf3b5c514b78b496f3b1df53fc37122a
#                 .addData(data);
#         }
#             geo_json_bf3b5c514b78b496f3b1df53fc37122a_add({&quot;bbox&quot;: [109.07493018100007, -6.899166055999956, 109.16167113100005, -6.839585382999928], &quot;features&quot;: [{&quot;bbox&quot;: [109.11269438500005, -6.899166055999956, 109.12271571300005, -6.890301474999944], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[109.12271571300005, -6.892172286999937, 0.0], [109.12271516300007, -6.892174399999931, 0.0], [109.12255509900007, -6.892789756999946, 0.0], [109.12242303900007, -6.8933001509999485, 0.0], [109.12230882500006, -6.89369990199998, 0.0], [109.12215535000007, -6.8940603889999466, 0.0], [109.12207682700006, -6.894385185999965, 0.0], [109.12204827400006, -6.894638598999961, 0.0], [109.12205541200007, -6.894824195999945, 0.0], [109.12206968900006, -6.89492413399995, 0.0], [109.12214464200008, -6.895138284999973, 0.0], [109.122162488000

# %% [markdown]
# Analysis Question:
# Kelurahan mana yang memiliki jumlah KK dengan kelas tertinggi (Merah Tua)?
#
# Jawab: Kelurahan Panggung
#
# Kelurahan apa saja yang tidak terdapat Sekolah Negeri?
#
# Jawab: Kelurahan Kaligangsa, Krandon, Cabawan, Muarareja, Pesurunganlor, Kalinyamatkulon, Sumurpanggang, Pesurungankidul, Kalinyamatwetan, Bandung, Tunon, Keturen, Debongkulon, Debongkidul, Debongtengah, Randugunting, Debonglor, Kraton, Kemandungan, Pekauman, Mintaragen, Mangkukusuman, Kejambon
